# %% [markdown]
# ## Date and time ranges

# %%
from datetime import datetime,date,time,timedelta

import polars as pl

# %%
start_date = date(2026,1,1)
end_date = date(2026,1,2)
interval = timedelta(hours=3)

# %% [markdown]
# ## Vertical ranges
#
# ### Datetime

# %%
pl.datetime_range(
    start=start_date,
    end=end_date,
    interval=interval,
    eager=True
).head(3)
# Out:
# shape: (3,)
# Series: 'literal' [datetime[μs]]
# [
# 	2026-01-01 00:00:00
# 	2026-01-01 03:00:00
# 	2026-01-01 06:00:00
# ]

# %% [markdown]
# ### Date range

# %%
pl.date_range(
    start=start_date,
    end=end_date,
    eager=True
).head(3)
# Out:
# shape: (2,)
# Series: 'literal' [date]
# [
# 	2026-01-01
# 	2026-01-02
# ]

# %% [markdown]
# Date range defaults to a one day interval but other intervals can be specified.
#
# ### Time range

# %%
start_time = time(0)
end_time = time(12)
interval = timedelta(hours=3)

pl.time_range(
    start=start_time,
    end=end_time,
    interval=interval,
    eager=True
)
# Out:
# shape: (5,)
# Series: 'literal' [time]
# [
# 	00:00:00
# 	03:00:00
# 	06:00:00
# 	09:00:00
# 	12:00:00
# ]

# %% [markdown]
# ## Lazy datetime ranges

# %% [markdown]
# Without setting `eager=True`, Polars uses lazy mode to run the code.

# %%
pl.datetime_range(
    start=start_date,
    end=end_date,
    interval=interval
)
# Out:
# <Expr ['2026-01-01.datetime_range([202…'] at 0x1E3A82CEC50>

# %%
type(pl.datetime_range(
    start=start_date,
    end=end_date,
    interval=interval,
    eager=False
))
# Out:
# polars.expr.expr.Expr

# %% [markdown]
# ## Horizontal datetime ranges

# %%
df = pl.DataFrame(
    {
        "id": ["A", "B"],
        "start":    [datetime(2026,1,1), datetime(2026,1,2)],
        "end": datetime(2026,1,3)
    }
)

df
# Out:
# shape: (2, 3)
# ┌─────┬─────────────────────┬─────────────────────┐
# │ id  ┆ start               ┆ end                 │
# │ --- ┆ ---                 ┆ ---                 │
# │ str ┆ datetime[μs]        ┆ datetime[μs]        │
# ╞═════╪═════════════════════╪═════════════════════╡
# │ A   ┆ 2026-01-01 00:00:00 ┆ 2026-01-03 00:00:00 │
# │ B   ┆ 2026-01-02 00:00:00 ┆ 2026-01-03 00:00:00 │
# └─────┴─────────────────────┴─────────────────────┘

# %%
df.with_columns(
    pl.date_ranges("start", "end", interval="1mo").alias("datetime_range")
)
# Out:
# shape: (2, 4)
# ┌─────┬─────────────────────┬─────────────────────┬────────────────┐
# │ id  ┆ start               ┆ end                 ┆ datetime_range │
# │ --- ┆ ---                 ┆ ---                 ┆ ---            │
# │ str ┆ datetime[μs]        ┆ datetime[μs]        ┆ list[date]     │
# ╞═════╪═════════════════════╪═════════════════════╪════════════════╡
# │ A   ┆ 2026-01-01 00:00:00 ┆ 2026-01-03 00:00:00 ┆ [2026-01-01]   │
# │ B   ┆ 2026-01-02 00:00:00 ┆ 2026-01-03 00:00:00 ┆ [2026-01-02]   │
# └─────┴─────────────────────┴─────────────────────┴────────────────┘

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# We have a short hourly temperature record with a gap at 2 am

# %%
df_weather = (
    pl.DataFrame(
        {
            "time": [time(0), time(1), time(3)], 
            "temperature": [12.0, 11, 9]
        }
    )
)
df_weather
# Out:
# shape: (3, 2)
# ┌──────────┬─────────────┐
# │ time     ┆ temperature │
# │ ---      ┆ ---         │
# │ time     ┆ f64         │
# ╞══════════╪═════════════╡
# │ 00:00:00 ┆ 12.0        │
# │ 01:00:00 ┆ 11.0        │
# │ 03:00:00 ┆ 9.0         │
# └──────────┴─────────────┘

# %% [markdown]
# We want to create an hourly `DataFrame` with no time gaps.
#
# First create a `DataFrame` where the `time` column has no gaps

# %%
df_time = pl.DataFrame({"time": pl.time_range(time(0), time(3), eager=True)})
df_time
# Out:
# shape: (4, 1)
# ┌──────────┐
# │ time     │
# │ ---      │
# │ time     │
# ╞══════════╡
# │ 00:00:00 │
# │ 01:00:00 │
# │ 02:00:00 │
# │ 03:00:00 │
# └──────────┘

# %% [markdown]
# Now do a left join of `df_weather` to `df_time`

# %%
df_time.join(
    df_weather,
    how="left",
    left_on="time",
    right_on="time",
    coalesce=True
)
# Out:
# shape: (4, 2)
# ┌──────────┬─────────────┐
# │ time     ┆ temperature │
# │ ---      ┆ ---         │
# │ time     ┆ f64         │
# ╞══════════╪═════════════╡
# │ 00:00:00 ┆ 12.0        │
# │ 01:00:00 ┆ 11.0        │
# │ 02:00:00 ┆ null        │
# │ 03:00:00 ┆ 9.0         │
# └──────────┴─────────────┘

# %% [markdown]
# Fill the gaps in the `temperature` column with linear interpolation

# %%
df_time.join(
    df_weather,
    how="left",
    left_on="time",
    right_on="time",
    coalesce=True
).with_columns(
    pl.col("temperature").interpolate()
)
# Out:
# shape: (4, 2)
# ┌──────────┬─────────────┐
# │ time     ┆ temperature │
# │ ---      ┆ ---         │
# │ time     ┆ f64         │
# ╞══════════╪═════════════╡
# │ 00:00:00 ┆ 12.0        │
# │ 01:00:00 ┆ 11.0        │
# │ 02:00:00 ┆ 10.0        │
# │ 03:00:00 ┆ 9.0         │
# └──────────┴─────────────┘

# %% [markdown]
# ### Exercise 2
# Our client is a bike shop and wants to look at sales during their summer and halloween sale periods.
#
# The client provides you with the following data for the start and end of each sale period

# %%
df_sales_periods = pl.DataFrame(
    {
        "sale":["Summer","Halloween"],
        "start": [date(2015, 6, 1), date(2015, 10, 15)],
        "end": [date(2015, 9, 1),date(2015, 11, 15)]
    }
)
df_sales_periods
# Out:
# shape: (2, 3)
# ┌───────────┬────────────┬────────────┐
# │ sale      ┆ start      ┆ end        │
# │ ---       ┆ ---        ┆ ---        │
# │ str       ┆ date       ┆ date       │
# ╞═══════════╪════════════╪════════════╡
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 │
# └───────────┴────────────┴────────────┘

# %% [markdown]
# Add a `date` column that has the range of dates between `start` and `end` on each row

# %%
df_sales_periods.with_columns(
    pl.date_ranges("start", "end").alias("date")
)
# Out:
# shape: (2, 4)
# ┌───────────┬────────────┬────────────┬─────────────────────────────────┐
# │ sale      ┆ start      ┆ end        ┆ date                            │
# │ ---       ┆ ---        ┆ ---        ┆ ---                             │
# │ str       ┆ date       ┆ date       ┆ list[date]                      │
# ╞═══════════╪════════════╪════════════╪═════════════════════════════════╡
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ [2015-06-01, 2015-06-02, … 201… │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ [2015-10-15, 2015-10-16, … 201… │
# └───────────┴────────────┴────────────┴─────────────────────────────────┘

# %% [markdown]
# Expand the list column to have a row for each element of the list

# %%
df_sales_periods.with_columns(
    pl.date_ranges("start", "end").alias("date")
).explode("date")
# Out:
# shape: (125, 4)
# ┌───────────┬────────────┬────────────┬────────────┐
# │ sale      ┆ start      ┆ end        ┆ date       │
# │ ---       ┆ ---        ┆ ---        ┆ ---        │
# │ str       ┆ date       ┆ date       ┆ date       │
# ╞═══════════╪════════════╪════════════╪════════════╡
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ 2015-06-01 │
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ 2015-06-02 │
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ 2015-06-03 │
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ 2015-06-04 │
# │ Summer    ┆ 2015-06-01 ┆ 2015-09-01 ┆ 2015-06-05 │
# │ …         ┆ …          ┆ …          ┆ …          │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ 2015-11-11 │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ 2015-11-12 │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ 2015-11-13 │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ 2015-11-14 │
# │ Halloween ┆ 2015-10-15 ┆ 2015-11-15 ┆ 2015-11-15 │
# └───────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# The bike sales data is in the following `DataFrame`

# %%
df_sales = pl.read_parquet("data/bike_sales.parquet")
df_sales.head(2)
# Out:
# shape: (2, 10)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬────────────┬──────┬─────────┐
# │ date       ┆ customer ┆ customer ┆ country   ┆ … ┆ unit cost ┆ unit price ┆ cost ┆ revenue │
# │ ---        ┆ age      ┆ gender   ┆ ---       ┆   ┆ ---       ┆ ---        ┆ ---  ┆ ---     │
# │ date       ┆ ---      ┆ ---      ┆ str       ┆   ┆ i64       ┆ i64        ┆ i64  ┆ i64     │
# │            ┆ i64      ┆ str      ┆           ┆   ┆           ┆            ┆      ┆         │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪════════════╪══════╪═════════╡
# │ 2013-01-28 ┆ 31       ┆ M        ┆ Australia ┆ … ┆ 1912      ┆ 3400       ┆ 1912 ┆ 2856    │
# │ 2015-01-28 ┆ 31       ┆ M        ┆ Australia ┆ … ┆ 1912      ┆ 3400       ┆ 1912 ┆ 2856    │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴────────────┴──────┴─────────┘

# %% [markdown]
# Join the sale periods to the full sales dataframe.
#
# Ensure that only rows that fall inside either the Summer or Halloween sale period are kept

# %%
df_sales.join(
    df_sales_periods.with_columns(pl.date_ranges("start", "end").alias("date")).explode(
        "date"
    ),
    on="date",
    how="inner",
)
# Out:
# shape: (1_994, 13)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬───────────┬───────────┬───────────┐
# │ date       ┆ customer  ┆ customer  ┆ country   ┆ … ┆ revenue ┆ sale      ┆ start     ┆ end       │
# │ ---        ┆ age       ┆ gender    ┆ ---       ┆   ┆ ---     ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ ---       ┆ ---       ┆ str       ┆   ┆ i64     ┆ str       ┆ date      ┆ date      │
# │            ┆ i64       ┆ str       ┆           ┆   ┆         ┆           ┆           ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪═══════════╪═══════════╪═══════════╡
# │ 2015-07-22 ┆ 31        ┆ M         ┆ Australia ┆ … ┆ 5712    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-07-04 ┆ 32        ┆ M         ┆ Australia ┆ … ┆ 2754    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-07-27 ┆ 32        ┆ M         ┆ Australia ┆ … ┆ 2835    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-07-04 ┆ 33        ┆ M         ┆ Australia ┆ … ┆ 8058    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-07-25 ┆ 33        ┆ M         ┆ Australia ┆ … ┆ 2686    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …       ┆ …         ┆ …         ┆ …         │
# │ 2015-10-23 ┆ 39        ┆ M         ┆ Australia ┆ … ┆ 4005    ┆ Halloween ┆ 2015-10-1 ┆ 2015-11-1 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 5         ┆ 5         │
# │ 2015-08-14 ┆ 30        ┆ F         ┆ Germany   ┆ … ┆ 690     ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-11-09 ┆ 31        ┆ F         ┆ United    ┆ … ┆ 2289    ┆ Halloween ┆ 2015-10-1 ┆ 2015-11-1 │
# │            ┆           ┆           ┆ Kingdom   ┆   ┆         ┆           ┆ 5         ┆ 5         │
# │ 2015-07-04 ┆ 22        ┆ M         ┆ United    ┆ … ┆ 1166    ┆ Summer    ┆ 2015-06-0 ┆ 2015-09-0 │
# │            ┆           ┆           ┆ Kingdom   ┆   ┆         ┆           ┆ 1         ┆ 1         │
# │ 2015-10-18 ┆ 22        ┆ M         ┆ United    ┆ … ┆ 1166    ┆ Halloween ┆ 2015-10-1 ┆ 2015-11-1 │
# │            ┆           ┆           ┆ Kingdom   ┆   ┆         ┆           ┆ 5         ┆ 5         │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# Aggregate the data by sale period and get the total cost and revenue for each sale period.
#
# Sort by revenue

# %%
df_sales.join(
    df_sales_periods.with_columns(pl.date_ranges("start", "end").alias("date")).explode(
        "date"
    ),
    on="date",
    how="inner",
).group_by(
    "sale"
).agg(
    pl.col("cost", "revenue").sum(),
).sort("revenue")
# Out:
# shape: (2, 3)
# ┌───────────┬─────────┬─────────┐
# │ sale      ┆ cost    ┆ revenue │
# │ ---       ┆ ---     ┆ ---     │
# │ str       ┆ i64     ┆ i64     │
# ╞═══════════╪═════════╪═════════╡
# │ Halloween ┆ 1136762 ┆ 1698624 │
# │ Summer    ┆ 2310151 ┆ 3476841 │
# └───────────┴─────────┴─────────┘
