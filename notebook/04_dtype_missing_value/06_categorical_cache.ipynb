# %% [markdown]
# # Categoricals and the string cache

# %%
import polars as pl

# %%
df = (
    pl.DataFrame(
        {
            "strings": ["c","b","a","c"], 
            "values": [1, 2, 3, 4]
        }
    )
    .with_columns(
        pl.col("strings").cast(pl.Categorical).alias("cats")
    )
)
df
# Out:
# shape: (4, 3)
# ┌─────────┬────────┬──────┐
# │ strings ┆ values ┆ cats │
# │ ---     ┆ ---    ┆ ---  │
# │ str     ┆ i64    ┆ cat  │
# ╞═════════╪════════╪══════╡
# │ c       ┆ 1      ┆ c    │
# │ b       ┆ 2      ┆ b    │
# │ a       ┆ 3      ┆ a    │
# │ c       ┆ 4      ┆ c    │
# └─────────┴────────┴──────┘

# %% [markdown]
# ## Filtering a categorical column
# We filter a categorical column like the way in normal string column

# %%
df.filter(
    cats = "b"
)
# Out:
# shape: (1, 3)
# ┌─────────┬────────┬──────┐
# │ strings ┆ values ┆ cats │
# │ ---     ┆ ---    ┆ ---  │
# │ str     ┆ i64    ┆ cat  │
# ╞═════════╪════════╪══════╡
# │ b       ┆ 2      ┆ b    │
# └─────────┴────────┴──────┘

# %% [markdown]
# We can also filter a categorical column with `is_in`

# %%
df.filter(
    pl.col("cats").is_in(["b"])
)
# Out:
# shape: (1, 3)
# ┌─────────┬────────┬──────┐
# │ strings ┆ values ┆ cats │
# │ ---     ┆ ---    ┆ ---  │
# │ str     ┆ i64    ┆ cat  │
# ╞═════════╪════════╪══════╡
# │ b       ┆ 2      ┆ b    │
# └─────────┴────────┴──────┘

# %% [markdown]
# ## Categorical from different `DataFrames`
#
# When we combine `DataFrames` that have categorical, Polars needs to ensure that the same mapping is used from strings to integers in both `DataFrames`.

# %%
df_right = (
    pl.DataFrame(
        {
            "strings": ["a","b"], 
            "values": [10, 20]
        }
    )
    .with_columns(
        pl.col("strings").cast(pl.Categorical).alias("cats")
    )
)
df_right
# Out:
# shape: (2, 3)
# ┌─────────┬────────┬──────┐
# │ strings ┆ values ┆ cats │
# │ ---     ┆ ---    ┆ ---  │
# │ str     ┆ i64    ┆ cat  │
# ╞═════════╪════════╪══════╡
# │ a       ┆ 10     ┆ a    │
# │ b       ┆ 20     ┆ b    │
# └─────────┴────────┴──────┘

# %%
df.join(
    df_right,
    on="cats",
    how="left",
    coalesce=True # merge join columns
)
# Out:
# shape: (4, 5)
# ┌─────────┬────────┬──────┬───────────────┬──────────────┐
# │ strings ┆ values ┆ cats ┆ strings_right ┆ values_right │
# │ ---     ┆ ---    ┆ ---  ┆ ---           ┆ ---          │
# │ str     ┆ i64    ┆ cat  ┆ str           ┆ i64          │
# ╞═════════╪════════╪══════╪═══════════════╪══════════════╡
# │ c       ┆ 1      ┆ c    ┆ null          ┆ null         │
# │ b       ┆ 2      ┆ b    ┆ b             ┆ 20           │
# │ a       ┆ 3      ┆ a    ┆ a             ┆ 10           │
# │ c       ┆ 4      ┆ c    ┆ null          ┆ null         │
# └─────────┴────────┴──────┴───────────────┴──────────────┘

# %% [markdown]
# ## Combining categoricals with the `StringCache`
# We can instead use a `StringCache` to ensure that different `DataFrames` have the same categorical mapping.
#
# The `StringCache` object:
# - stores the categorical mapping
# - ensures that all `DataFrames` use the same mapping.
#
# We can use the `StringCache`:
# - inside a context manager or by enabling it globally.
#
# ### Using the `StringCache` inside a context-manager
#
# A context-manager is a way to ensure certain actions happen in Python.
#
# Everything inside the code block beginning with `with` is in the same context.

# %%
with pl.StringCache():
    # Left df
    df = pl.DataFrame(
        {"strings": ["c", "b", "a", "c"], "values": [1, 2, 3, 4]}
    )\
    .with_columns(pl.col("strings").cast(pl.Categorical).alias("cats"))
    # Right df
    df_right = pl.DataFrame(
        {"strings": ["a", "b"], "values": [10, 20]}
    )\
    .with_columns(
        pl.col("strings").cast(pl.Categorical).alias("cats")
    )
    # Join
    df_joined = df.join(
        df_right,
        on="cats",
        how="left",
        coalesce=True
    )

df_joined
# Out:
# shape: (4, 5)
# ┌─────────┬────────┬──────┬───────────────┬──────────────┐
# │ strings ┆ values ┆ cats ┆ strings_right ┆ values_right │
# │ ---     ┆ ---    ┆ ---  ┆ ---           ┆ ---          │
# │ str     ┆ i64    ┆ cat  ┆ str           ┆ i64          │
# ╞═════════╪════════╪══════╪═══════════════╪══════════════╡
# │ c       ┆ 1      ┆ c    ┆ null          ┆ null         │
# │ b       ┆ 2      ┆ b    ┆ b             ┆ 20           │
# │ a       ┆ 3      ┆ a    ┆ a             ┆ 10           │
# │ c       ┆ 4      ┆ c    ┆ null          ┆ null         │
# └─────────┴────────┴──────┴───────────────┴──────────────┘

# %% [markdown]
# ### Enabling the `StringCache`
# We can enable the `StringCache` to be on through a session - be aware that this can have affects beyond this script/notebook.

# %%
# pl.enable_string_cache()

# %% [markdown]
# When we use `pl.enable_string_cache()` Polars enables a `StringCache` that is used by all categorical columns until:
# - the end of the session or
# - call `pl.disable_string_cache()`
#
# You can see whether a string cache is enabled with

# %%
pl.using_string_cache()
# Out:
# True

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# Create a `DataFrame` from the Titanic dataset and cast the `Pclass` column to categorical.

# %%
csv_file = "data/titanic.csv"

df = pl.read_csv(csv_file).with_columns(
    pl.col("Pclass").cast(pl.Utf8).cast(pl.Categorical)
)

df.head(5)
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ cat    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 5           ┆ 0        ┆ 3      ┆ Allen, Mr.        ┆ … ┆ 373450    ┆ 8.05    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ William Henry     ┆   ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %% [markdown]
# Continue by casting the `Embarked` column to categorical (change `with_column` to `with_columns`).

# %%
df = df.with_columns(
    pl.col("Embarked").cast(pl.Categorical)
)

df.head(5)
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ cat    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ cat      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 5           ┆ 0        ┆ 3      ┆ Allen, Mr.        ┆ … ┆ 373450    ┆ 8.05    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ William Henry     ┆   ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %% [markdown]
# Filter the `Pclass` column for third class passengers

# %%
df.filter(
    Pclass = "3"
).head(5)
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬────────────────────┬───┬───────────┬────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name               ┆ … ┆ Ticket    ┆ Fare   ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                ┆   ┆ ---       ┆ ---    ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ cat    ┆ str                ┆   ┆ str       ┆ f64    ┆ str   ┆ cat      │
# ╞═════════════╪══════════╪════════╪════════════════════╪═══╪═══════════╪════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen   ┆ … ┆ A/5 21171 ┆ 7.25   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris             ┆   ┆           ┆        ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.   ┆ … ┆ STON/O2.  ┆ 7.925  ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina              ┆   ┆ 3101282   ┆        ┆       ┆          │
# │ 5           ┆ 0        ┆ 3      ┆ Allen, Mr. William ┆ … ┆ 373450    ┆ 8.05   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Henry              ┆   ┆           ┆        ┆       ┆          │
# │ 6           ┆ 0        ┆ 3      ┆ Moran, Mr. James   ┆ … ┆ 330877    ┆ 8.4583 ┆ null  ┆ Q        │
# │ 8           ┆ 0        ┆ 3      ┆ Palsson, Master.   ┆ … ┆ 349909    ┆ 21.075 ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Gosta Leonard      ┆   ┆           ┆        ┆       ┆          │
# └─────────────┴──────────┴────────┴────────────────────┴───┴───────────┴────────┴───────┴──────────┘

# %% [markdown]
# Add a filter on the `Embarked` column for passengers who embarked in either Southampton (`S`) or Queenstown (`Q`)

# %%
df.filter(
    (pl.col("Embarked").is_in(["S", "Q"])) & (pl.col("Pclass") == "3")
).head(5)
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬────────────────────┬───┬───────────┬────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name               ┆ … ┆ Ticket    ┆ Fare   ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---                ┆   ┆ ---       ┆ ---    ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ cat    ┆ str                ┆   ┆ str       ┆ f64    ┆ str   ┆ cat      │
# ╞═════════════╪══════════╪════════╪════════════════════╪═══╪═══════════╪════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen   ┆ … ┆ A/5 21171 ┆ 7.25   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris             ┆   ┆           ┆        ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.   ┆ … ┆ STON/O2.  ┆ 7.925  ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina              ┆   ┆ 3101282   ┆        ┆       ┆          │
# │ 5           ┆ 0        ┆ 3      ┆ Allen, Mr. William ┆ … ┆ 373450    ┆ 8.05   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Henry              ┆   ┆           ┆        ┆       ┆          │
# │ 6           ┆ 0        ┆ 3      ┆ Moran, Mr. James   ┆ … ┆ 330877    ┆ 8.4583 ┆ null  ┆ Q        │
# │ 8           ┆ 0        ┆ 3      ┆ Palsson, Master.   ┆ … ┆ 349909    ┆ 21.075 ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Gosta Leonard      ┆   ┆           ┆        ┆       ┆          │
# └─────────────┴──────────┴────────┴────────────────────┴───┴───────────┴────────┴───────┴──────────┘

# %% [markdown]
# ### Exercise 2
# Filter the Spotify `DataFrame` to find all tracks by either Taylor Swift or Ed Sheeran.

# %%
spotify_csv = "data/spotify-charts-2017-2021-global-top200.csv.gz"

# %% [markdown]
# Enable the string cache

# %%
pl.enable_string_cache()

# %%
spotify_df = pl.read_csv(spotify_csv)

spotify_df.head(5)
# Out:
# shape: (5, 9)
# ┌───────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬──────────────┬─────────┐
# │ title         ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend        ┆ streams │
# │ ---           ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---          ┆ ---     │
# │ str           ┆ i64  ┆ str        ┆ str           ┆   ┆ str    ┆ str    ┆ str          ┆ i64     │
# ╞═══════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪══════════════╪═════════╡
# │ Starboy       ┆ 1    ┆ 2017-01-01 ┆ The Weeknd,   ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3135625 │
# │               ┆      ┆            ┆ Daft Punk     ┆   ┆        ┆        ┆ N            ┆         │
# │ Closer        ┆ 2    ┆ 2017-01-01 ┆ The           ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3015525 │
# │               ┆      ┆            ┆ Chainsmokers, ┆   ┆        ┆        ┆ N            ┆         │
# │               ┆      ┆            ┆ Halsey        ┆   ┆        ┆        ┆              ┆         │
# │ Let Me Love   ┆ 3    ┆ 2017-01-01 ┆ DJ Snake,     ┆ … ┆ Global ┆ top200 ┆ MOVE_UP      ┆ 2545384 │
# │ You           ┆      ┆            ┆ Justin Bieber ┆   ┆        ┆        ┆              ┆         │
# │ Rockabye      ┆ 4    ┆ 2017-01-01 ┆ Clean Bandit  ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN    ┆ 2356604 │
# │ (feat. Sean   ┆      ┆            ┆               ┆   ┆        ┆        ┆              ┆         │
# │ Paul & An…    ┆      ┆            ┆               ┆   ┆        ┆        ┆              ┆         │
# │ One Dance     ┆ 5    ┆ 2017-01-01 ┆ Drake,        ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 2259887 │
# │               ┆      ┆            ┆ WizKid, Kyla  ┆   ┆        ┆        ┆ N            ┆         │
# └───────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴──────────────┴─────────┘

# %%
spotify_df.with_columns(
        pl.col("artist").cast(pl.Categorical)
    )\
    .filter(
        pl.col("artist").is_in(["Taylor Swift", "Ed Sheeran"])
    ).head(6)
# Out:
# shape: (6, 9)
# ┌──────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬───────────────┬─────────┐
# │ title        ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams │
# │ ---          ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---     │
# │ str          ┆ i64  ┆ str        ┆ cat        ┆   ┆ str    ┆ str    ┆ str           ┆ i64     │
# ╞══════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═══════════════╪═════════╡
# │ Photograph   ┆ 123  ┆ 2017-01-01 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 472142  │
# │ Thinking out ┆ 141  ┆ 2017-01-01 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 436476  │
# │ Loud         ┆      ┆            ┆            ┆   ┆        ┆        ┆               ┆         │
# │ Photograph   ┆ 91   ┆ 2017-01-02 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 595989  │
# │ Thinking out ┆ 109  ┆ 2017-01-02 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 536343  │
# │ Loud         ┆      ┆            ┆            ┆   ┆        ┆        ┆               ┆         │
# │ Perfect      ┆ 27   ┆ 2018-03-01 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 1835597 │
# │ Shape of You ┆ 34   ┆ 2018-03-01 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 1616893 │
# └──────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴───────────────┴─────────┘

# %% [markdown]
# Then disable the string cache

# %%
pl.disable_string_cache()
