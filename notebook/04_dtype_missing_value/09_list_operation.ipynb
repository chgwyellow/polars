# %% [markdown]
# # Using expressions on List columns

# %%
import polars as pl

# %%
df = (
    pl.DataFrame(
        {
            'values':[ 
                [0,1], 
                [2,3,4],
                [4,5,6,7,8]
            ],
        }
    )
)
df
# Out:
# shape: (3, 1)
# ┌─────────────┐
# │ values      │
# │ ---         │
# │ list[i64]   │
# ╞═════════════╡
# │ [0, 1]      │
# │ [2, 3, 4]   │
# │ [4, 5, … 8] │
# └─────────────┘

# %% [markdown]
# ## The list expression namespace
# Polars has a `.list` [namespace](https://pola-rs.github.io/polars/py-polars/html/reference/expressions/list.html) for expressions that work on `pl.List` columns
#
#
# ## Selecting data in lists

# %%
df\
.with_columns(
    [
        pl.col("values").list.first().alias("first"),
        pl.col("values").list.last().alias("last"),
        pl.col("values").list.head(2).alias("head"),
        pl.col("values").list.tail(2).alias("tail"),
        pl.col("values").list.slice(1,2).alias("slice"),
    ]
)
# Out:
# shape: (3, 6)
# ┌─────────────┬───────┬──────┬───────────┬───────────┬───────────┐
# │ values      ┆ first ┆ last ┆ head      ┆ tail      ┆ slice     │
# │ ---         ┆ ---   ┆ ---  ┆ ---       ┆ ---       ┆ ---       │
# │ list[i64]   ┆ i64   ┆ i64  ┆ list[i64] ┆ list[i64] ┆ list[i64] │
# ╞═════════════╪═══════╪══════╪═══════════╪═══════════╪═══════════╡
# │ [0, 1]      ┆ 0     ┆ 1    ┆ [0, 1]    ┆ [0, 1]    ┆ [1]       │
# │ [2, 3, 4]   ┆ 2     ┆ 4    ┆ [2, 3]    ┆ [3, 4]    ┆ [3, 4]    │
# │ [4, 5, … 8] ┆ 4     ┆ 8    ┆ [4, 5]    ┆ [7, 8]    ┆ [5, 6]    │
# └─────────────┴───────┴──────┴───────────┴───────────┴───────────┘

# %% [markdown]
# To get a specific row we use `list.get` to select a value by a position `index` in each list

# %%
df.with_columns(
    [
        pl.col("values").list.get(0).alias("first"),
        pl.col("values").list.get(1).alias("second"),
        pl.col("values").list.get(-1).alias("last"),
    ]
)
# Out:
# shape: (3, 4)
# ┌─────────────┬───────┬────────┬──────┐
# │ values      ┆ first ┆ second ┆ last │
# │ ---         ┆ ---   ┆ ---    ┆ ---  │
# │ list[i64]   ┆ i64   ┆ i64    ┆ i64  │
# ╞═════════════╪═══════╪════════╪══════╡
# │ [0, 1]      ┆ 0     ┆ 1      ┆ 1    │
# │ [2, 3, 4]   ┆ 2     ┆ 3      ┆ 4    │
# │ [4, 5, … 8] ┆ 4     ┆ 5      ┆ 8    │
# └─────────────┴───────┴────────┴──────┘

# %% [markdown]
# Check whether each list contains a value with `list.contains`

# %%
df\
.with_columns(
    [
        pl.col("values").list.contains(i).alias(str(i)) for i in range(3)
    ]
)
# Out:
# shape: (3, 4)
# ┌─────────────┬───────┬───────┬───────┐
# │ values      ┆ 0     ┆ 1     ┆ 2     │
# │ ---         ┆ ---   ┆ ---   ┆ ---   │
# │ list[i64]   ┆ bool  ┆ bool  ┆ bool  │
# ╞═════════════╪═══════╪═══════╪═══════╡
# │ [0, 1]      ┆ true  ┆ true  ┆ false │
# │ [2, 3, 4]   ┆ false ┆ false ┆ true  │
# │ [4, 5, … 8] ┆ false ┆ false ┆ false │
# └─────────────┴───────┴───────┴───────┘

# %%
df\
.with_columns(
    four = pl.lit(4)
)
# Out:
# shape: (3, 2)
# ┌─────────────┬──────┐
# │ values      ┆ four │
# │ ---         ┆ ---  │
# │ list[i64]   ┆ i32  │
# ╞═════════════╪══════╡
# │ [0, 1]      ┆ 4    │
# │ [2, 3, 4]   ┆ 4    │
# │ [4, 5, … 8] ┆ 4    │
# └─────────────┴──────┘

# %%
df\
.with_columns(
    four = pl.lit(4)
)\
.with_columns(
    pl.col("values").list.contains(pl.col("four")).alias("has_four")
)
# Out:
# shape: (3, 3)
# ┌─────────────┬──────┬──────────┐
# │ values      ┆ four ┆ has_four │
# │ ---         ┆ ---  ┆ ---      │
# │ list[i64]   ┆ i32  ┆ bool     │
# ╞═════════════╪══════╪══════════╡
# │ [0, 1]      ┆ 4    ┆ false    │
# │ [2, 3, 4]   ┆ 4    ┆ true     │
# │ [4, 5, … 8] ┆ 4    ┆ true     │
# └─────────────┴──────┴──────────┘

# %%
df2 = (
    pl.DataFrame(
        {
            'values':[ 
                [0,1,0], 
                [2,3],
                [4,5,6,7,8]
            ],
            'values_2':[ 
                [0], 
                [2,3,4],
                [4,5,9]
            ],

        }
    )
)
df2
# Out:
# shape: (3, 2)
# ┌─────────────┬───────────┐
# │ values      ┆ values_2  │
# │ ---         ┆ ---       │
# │ list[i64]   ┆ list[i64] │
# ╞═════════════╪═══════════╡
# │ [0, 1, 0]   ┆ [0]       │
# │ [2, 3]      ┆ [2, 3, 4] │
# │ [4, 5, … 8] ┆ [4, 5, 9] │
# └─────────────┴───────────┘

# %% [markdown]
# Find all unique values in an list with `list.unique`

# %%
df2\
.select(
    "values",
    pl.col("values").list.unique().alias("unique")
)
# Out:
# shape: (3, 2)
# ┌─────────────┬─────────────┐
# │ values      ┆ unique      │
# │ ---         ┆ ---         │
# │ list[i64]   ┆ list[i64]   │
# ╞═════════════╪═════════════╡
# │ [0, 1, 0]   ┆ [0, 1]      │
# │ [2, 3]      ┆ [2, 3]      │
# │ [4, 5, … 8] ┆ [4, 5, … 8] │
# └─────────────┴─────────────┘

# %% [markdown]
# - `set_intersection` gets the common values between lists
# - `set_difference` gets values that are in the left list but not in the right list
# - `set_symmetric_difference` gets values that are not in both lists
# - `set_union` gets the unique values from both lists

# %%
df2
# Out:
# shape: (3, 2)
# ┌─────────────┬───────────┐
# │ values      ┆ values_2  │
# │ ---         ┆ ---       │
# │ list[i64]   ┆ list[i64] │
# ╞═════════════╪═══════════╡
# │ [0, 1, 0]   ┆ [0]       │
# │ [2, 3]      ┆ [2, 3, 4] │
# │ [4, 5, … 8] ┆ [4, 5, 9] │
# └─────────────┴───────────┘

# %%
df2\
.with_columns(
    pl.col("values").list.set_intersection(pl.col("values_2")).alias("intersection"),
    pl.col("values").list.set_difference(pl.col("values_2")).alias("difference"),
    pl.col("values").list.set_symmetric_difference(pl.col("values_2")).alias("symmetric_difference"),
    pl.col("values").list.set_union(pl.col("values_2")).alias("union"),
)
# Out:
# shape: (3, 6)
# ┌─────────────┬───────────┬──────────────┬────────────┬──────────────────────┬─────────────┐
# │ values      ┆ values_2  ┆ intersection ┆ difference ┆ symmetric_difference ┆ union       │
# │ ---         ┆ ---       ┆ ---          ┆ ---        ┆ ---                  ┆ ---         │
# │ list[i64]   ┆ list[i64] ┆ list[i64]    ┆ list[i64]  ┆ list[i64]            ┆ list[i64]   │
# ╞═════════════╪═══════════╪══════════════╪════════════╪══════════════════════╪═════════════╡
# │ [0, 1, 0]   ┆ [0]       ┆ [0]          ┆ [1]        ┆ [1]                  ┆ [0, 1]      │
# │ [2, 3]      ┆ [2, 3, 4] ┆ [2, 3]       ┆ []         ┆ [4]                  ┆ [2, 3, 4]   │
# │ [4, 5, … 8] ┆ [4, 5, 9] ┆ [4, 5]       ┆ [8, 7, 6]  ┆ [6, 7, … 9]          ┆ [4, 5, … 9] │
# └─────────────┴───────────┴──────────────┴────────────┴──────────────────────┴─────────────┘

# %% [markdown]
# ### Re-ordering values in each list
#
# - `reverse` reverses the order of the list
# - `sort` sorts each list
# - `shift` moves values in each list so the first values are `null`

# %%
df
# Out:
# shape: (3, 1)
# ┌─────────────┐
# │ values      │
# │ ---         │
# │ list[i64]   │
# ╞═════════════╡
# │ [0, 1]      │
# │ [2, 3, 4]   │
# │ [4, 5, … 8] │
# └─────────────┘

# %%
df\
.with_columns(
    pl.col("values").list.reverse().alias("reverse"),
    pl.col("values").list.sort().alias("sort"),
    pl.col("values").list.shift(1).alias("shift"),
)
# Out:
# shape: (3, 4)
# ┌─────────────┬─────────────┬─────────────┬────────────────┐
# │ values      ┆ reverse     ┆ sort        ┆ shift          │
# │ ---         ┆ ---         ┆ ---         ┆ ---            │
# │ list[i64]   ┆ list[i64]   ┆ list[i64]   ┆ list[i64]      │
# ╞═════════════╪═════════════╪═════════════╪════════════════╡
# │ [0, 1]      ┆ [1, 0]      ┆ [0, 1]      ┆ [null, 0]      │
# │ [2, 3, 4]   ┆ [4, 3, 2]   ┆ [2, 3, 4]   ┆ [null, 2, 3]   │
# │ [4, 5, … 8] ┆ [8, 7, … 4] ┆ [4, 5, … 8] ┆ [null, 4, … 7] │
# └─────────────┴─────────────┴─────────────┴────────────────┘

# %% [markdown]
# ### List aggregations

# %%
df\
.with_columns(
    pl.col("values").list.len().alias("lengths"),
    pl.col("values").list.min().alias("min"),
    pl.col("values").list.mean().alias("mean"),
    pl.col("values").list.max().alias("max"),
)
# Out:
# shape: (3, 5)
# ┌─────────────┬─────────┬─────┬──────┬─────┐
# │ values      ┆ lengths ┆ min ┆ mean ┆ max │
# │ ---         ┆ ---     ┆ --- ┆ ---  ┆ --- │
# │ list[i64]   ┆ u32     ┆ i64 ┆ f64  ┆ i64 │
# ╞═════════════╪═════════╪═════╪══════╪═════╡
# │ [0, 1]      ┆ 2       ┆ 0   ┆ 0.5  ┆ 1   │
# │ [2, 3, 4]   ┆ 3       ┆ 2   ┆ 3.0  ┆ 4   │
# │ [4, 5, … 8] ┆ 5       ┆ 4   ┆ 6.0  ┆ 8   │
# └─────────────┴─────────┴─────┴──────┴─────┘

# %% [markdown]
# ## Calling expressions on each list
# Each row in a `pl.List` column is a `Series`.

# %%
pl.DataFrame(
    {
        "values": [[0, 1], [4, 3, 2]],
    }
)\
.with_columns(
    pl.col("values").list.eval( # eval run any polar's expression against the list's elements
        pl.element().rank(method="ordinal")
    ).alias("eval")
)
# Out:
# shape: (2, 2)
# ┌───────────┬───────────┐
# │ values    ┆ eval      │
# │ ---       ┆ ---       │
# │ list[i64] ┆ list[u32] │
# ╞═══════════╪═══════════╡
# │ [0, 1]    ┆ [1, 2]    │
# │ [4, 3, 2] ┆ [3, 2, 1] │
# └───────────┴───────────┘

# %% [markdown]
# Call `element()` without any functions following.

# %%
pl.DataFrame(
    {
        "values": [[0, 1], [4, 3, 2]],
    }
)\
.with_columns(
    pl.col("values").list.eval(
        pl.element()
    ).alias("eval")
)
# Out:
# shape: (2, 2)
# ┌───────────┬───────────┐
# │ values    ┆ eval      │
# │ ---       ┆ ---       │
# │ list[i64] ┆ list[i64] │
# ╞═══════════╪═══════════╡
# │ [0, 1]    ┆ [0, 1]    │
# │ [4, 3, 2] ┆ [4, 3, 2] │
# └───────────┴───────────┘

# %% [markdown]
# `element()` with `filter()`

# %%
pl.DataFrame(
    {
        "values": [[0,None,1], [2,3,None]],
    }
)\
.with_columns(
    pl.col("values").list.eval(
        pl.element().filter(
            pl.element().is_not_null()
        )
    ).alias("eval")
)
# Out:
# shape: (2, 2)
# ┌──────────────┬───────────┐
# │ values       ┆ eval      │
# │ ---          ┆ ---       │
# │ list[i64]    ┆ list[i64] │
# ╞══════════════╪═══════════╡
# │ [0, null, 1] ┆ [0, 1]    │
# │ [2, 3, null] ┆ [2, 3]    │
# └──────────────┴───────────┘

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# We need to parse the following address strings to get columns with the:
# - number
# - street
# - city
# - state
# - zipcode

# %%
pl.Config.set_fmt_str_lengths(150)
addresses = [
    '93 NORTH 9TH STREET, BROOKLYN NY 11211',
    '380 WESTMINSTER ST, PROVIDENCE RI 02903',
    '177 MAIN STREET, LITTLETON NH 03561'
]

df = (
    pl.DataFrame(
        {"address":addresses}
    )
)
df
# Out:
# shape: (3, 1)
# ┌─────────────────────────────────────────┐
# │ address                                 │
# │ ---                                     │
# │ str                                     │
# ╞═════════════════════════════════════════╡
# │ 93 NORTH 9TH STREET, BROOKLYN NY 11211  │
# │ 380 WESTMINSTER ST, PROVIDENCE RI 02903 │
# │ 177 MAIN STREET, LITTLETON NH 03561     │
# └─────────────────────────────────────────┘

# %% [markdown]
# Add a column called `split` with the string split by whitespace (using `str.split`) into a list column

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)
# Out:
# shape: (3, 2)
# ┌─────────────────────────────────────────┬───────────────────────────────────┐
# │ address                                 ┆ split                             │
# │ ---                                     ┆ ---                               │
# │ str                                     ┆ list[str]                         │
# ╞═════════════════════════════════════════╪═══════════════════════════════════╡
# │ 93 NORTH 9TH STREET, BROOKLYN NY 11211  ┆ ["93", "NORTH", … "11211"]        │
# │ 380 WESTMINSTER ST, PROVIDENCE RI 02903 ┆ ["380", "WESTMINSTER", … "02903"] │
# │ 177 MAIN STREET, LITTLETON NH 03561     ┆ ["177", "MAIN", … "03561"]        │
# └─────────────────────────────────────────┴───────────────────────────────────┘

# %% [markdown]
# In an additional `with_column` statement add a 32-bit integer column called `number` using the `first` element of each list

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number")
)
# Out:
# shape: (3, 3)
# ┌─────────────────────────────────────────┬───────────────────────────────────┬────────┐
# │ address                                 ┆ split                             ┆ number │
# │ ---                                     ┆ ---                               ┆ ---    │
# │ str                                     ┆ list[str]                         ┆ i32    │
# ╞═════════════════════════════════════════╪═══════════════════════════════════╪════════╡
# │ 93 NORTH 9TH STREET, BROOKLYN NY 11211  ┆ ["93", "NORTH", … "11211"]        ┆ 93     │
# │ 380 WESTMINSTER ST, PROVIDENCE RI 02903 ┆ ["380", "WESTMINSTER", … "02903"] ┆ 380    │
# │ 177 MAIN STREET, LITTLETON NH 03561     ┆ ["177", "MAIN", … "03561"]        ┆ 177    │
# └─────────────────────────────────────────┴───────────────────────────────────┴────────┘

# %% [markdown]
# The street component of the address runs from the second element of the list to the element of the list that contains a comma.
#
# Add a list column called `contains_comma` where we check if each element in the lists in `split` contain a comma.
#
# Use `eval` to run the `str.contains` expression on each element in the list

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number"),
    pl.col("split").list.eval(
        pl.element().str.contains(",")
    ).alias("contains_comma")
)
# Out:
# shape: (3, 4)
# ┌──────────────────────────────────┬────────────────────────────┬────────┬─────────────────────────┐
# │ address                          ┆ split                      ┆ number ┆ contains_comma          │
# │ ---                              ┆ ---                        ┆ ---    ┆ ---                     │
# │ str                              ┆ list[str]                  ┆ i32    ┆ list[bool]              │
# ╞══════════════════════════════════╪════════════════════════════╪════════╪═════════════════════════╡
# │ 93 NORTH 9TH STREET, BROOKLYN NY ┆ ["93", "NORTH", … "11211"] ┆ 93     ┆ [false, false, … false] │
# │ 11211                            ┆                            ┆        ┆                         │
# │ 380 WESTMINSTER ST, PROVIDENCE   ┆ ["380", "WESTMINSTER", …   ┆ 380    ┆ [false, false, … false] │
# │ RI 02903                         ┆ "02903"]                   ┆        ┆                         │
# │ 177 MAIN STREET, LITTLETON NH    ┆ ["177", "MAIN", … "03561"] ┆ 177    ┆ [false, false, … false] │
# │ 03561                            ┆                            ┆        ┆                         │
# └──────────────────────────────────┴────────────────────────────┴────────┴─────────────────────────┘

# %% [markdown]
# With a new call to `with_column` slice each list in `split` from the second element to the index of the element that contains a comma.
#
# Hint 1: `list.arg_max` expression that finds the index of the largest value in an list.

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number"),
    pl.col("split").list.eval(
        pl.element().str.contains(",")
    ).alias("contains_comma")
)\
.with_columns(
    pl.col("split").list.slice(1, pl.col("contains_comma").list.arg_max()).alias("street")
)
# Out:
# shape: (3, 5)
# ┌─────────────────────────┬───────────────────┬────────┬──────────────────┬────────────────────────┐
# │ address                 ┆ split             ┆ number ┆ contains_comma   ┆ street                 │
# │ ---                     ┆ ---               ┆ ---    ┆ ---              ┆ ---                    │
# │ str                     ┆ list[str]         ┆ i32    ┆ list[bool]       ┆ list[str]              │
# ╞═════════════════════════╪═══════════════════╪════════╪══════════════════╪════════════════════════╡
# │ 93 NORTH 9TH STREET,    ┆ ["93", "NORTH", … ┆ 93     ┆ [false, false, … ┆ ["NORTH", "9TH",       │
# │ BROOKLYN NY 11211       ┆ "11211"]          ┆        ┆ false]           ┆ "STREET,"]             │
# │ 380 WESTMINSTER ST,     ┆ ["380",           ┆ 380    ┆ [false, false, … ┆ ["WESTMINSTER", "ST,"] │
# │ PROVIDENCE RI 02903     ┆ "WESTMINSTER", …  ┆        ┆ false]           ┆                        │
# │                         ┆ "02903"]          ┆        ┆                  ┆                        │
# │ 177 MAIN STREET,        ┆ ["177", "MAIN", … ┆ 177    ┆ [false, false, … ┆ ["MAIN", "STREET,"]    │
# │ LITTLETON NH 03561      ┆ "03561"]          ┆        ┆ false]           ┆                        │
# └─────────────────────────┴───────────────────┴────────┴──────────────────┴────────────────────────┘

# %% [markdown]
# Polars has a similar method called `list.join`.
#
# Join the string lists in `street` using `list.join` (with a " " separating the strings)

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number"),
    pl.col("split").list.eval(
        pl.element().str.contains(",")
    ).alias("contains_comma")
)\
.with_columns(
    pl.col("split").list.slice(1, pl.col("contains_comma").list.arg_max()).list.join(separator=" ").alias("street")
)
# Out:
# shape: (3, 5)
# ┌──────────────────────────────┬───────────────────┬────────┬──────────────────┬───────────────────┐
# │ address                      ┆ split             ┆ number ┆ contains_comma   ┆ street            │
# │ ---                          ┆ ---               ┆ ---    ┆ ---              ┆ ---               │
# │ str                          ┆ list[str]         ┆ i32    ┆ list[bool]       ┆ str               │
# ╞══════════════════════════════╪═══════════════════╪════════╪══════════════════╪═══════════════════╡
# │ 93 NORTH 9TH STREET,         ┆ ["93", "NORTH", … ┆ 93     ┆ [false, false, … ┆ NORTH 9TH STREET, │
# │ BROOKLYN NY 11211            ┆ "11211"]          ┆        ┆ false]           ┆                   │
# │ 380 WESTMINSTER ST,          ┆ ["380",           ┆ 380    ┆ [false, false, … ┆ WESTMINSTER ST,   │
# │ PROVIDENCE RI 02903          ┆ "WESTMINSTER", …  ┆        ┆ false]           ┆                   │
# │                              ┆ "02903"]          ┆        ┆                  ┆                   │
# │ 177 MAIN STREET, LITTLETON   ┆ ["177", "MAIN", … ┆ 177    ┆ [false, false, … ┆ MAIN STREET,      │
# │ NH 03561                     ┆ "03561"]          ┆        ┆ false]           ┆                   │
# └──────────────────────────────┴───────────────────┴────────┴──────────────────┴───────────────────┘

# %% [markdown]
# Extract the `city` from `split` by slicing.
#
# The slice should start from the `arg_max` value in `contains_command` and have a length of 1

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number"),
    pl.col("split").list.eval(
        pl.element().str.contains(",")
    ).alias("contains_comma")
)\
.with_columns(
    pl.col("split").list.slice(1, pl.col("contains_comma").list.arg_max()).list.join(separator=" ").alias("street")
)\
.with_columns(
    pl.col("split").list.slice(pl.col("contains_comma").list.arg_max() + 1, 1).alias("city")
)
# Out:
# shape: (3, 6)
# ┌──────────────────┬─────────────────┬────────┬─────────────────┬─────────────────┬────────────────┐
# │ address          ┆ split           ┆ number ┆ contains_comma  ┆ street          ┆ city           │
# │ ---              ┆ ---             ┆ ---    ┆ ---             ┆ ---             ┆ ---            │
# │ str              ┆ list[str]       ┆ i32    ┆ list[bool]      ┆ str             ┆ list[str]      │
# ╞══════════════════╪═════════════════╪════════╪═════════════════╪═════════════════╪════════════════╡
# │ 93 NORTH 9TH     ┆ ["93", "NORTH", ┆ 93     ┆ [false, false,  ┆ NORTH 9TH       ┆ ["BROOKLYN"]   │
# │ STREET, BROOKLYN ┆ … "11211"]      ┆        ┆ … false]        ┆ STREET,         ┆                │
# │ NY 11211         ┆                 ┆        ┆                 ┆                 ┆                │
# │ 380 WESTMINSTER  ┆ ["380",         ┆ 380    ┆ [false, false,  ┆ WESTMINSTER ST, ┆ ["PROVIDENCE"] │
# │ ST, PROVIDENCE   ┆ "WESTMINSTER",  ┆        ┆ … false]        ┆                 ┆                │
# │ RI 02903         ┆ … "02903"]      ┆        ┆                 ┆                 ┆                │
# │ 177 MAIN STREET, ┆ ["177", "MAIN", ┆ 177    ┆ [false, false,  ┆ MAIN STREET,    ┆ ["LITTLETON"]  │
# │ LITTLETON NH     ┆ … "03561"]      ┆        ┆ … false]        ┆                 ┆                │
# │ 03561            ┆                 ┆        ┆                 ┆                 ┆                │
# └──────────────────┴─────────────────┴────────┴─────────────────┴─────────────────┴────────────────┘

# %% [markdown]
# Get the `zipcode` as the last element in `split`

# %%
df\
.with_columns(
    pl.col("address").str.split(" ").alias("split")
)\
.with_columns(
    pl.col("split").list.first().cast(pl.Int32).alias("number"),
    pl.col("split").list.eval(
        pl.element().str.contains(",")
    ).alias("contains_comma")
)\
.with_columns(
    pl.col("split").list.slice(1, pl.col("contains_comma").list.arg_max()).list.join(separator=" ").alias("street")
)\
.with_columns(
    pl.col("split").list.slice(pl.col("contains_comma").list.arg_max() + 1, 1).alias("city"),
    pl.col("split").list.last().cast(pl.Int32).alias("zipcode")
)
# Out:
# shape: (3, 7)
# ┌───────────────┬───────────────┬────────┬───────────────┬───────────────┬───────────────┬─────────┐
# │ address       ┆ split         ┆ number ┆ contains_comm ┆ street        ┆ city          ┆ zipcode │
# │ ---           ┆ ---           ┆ ---    ┆ a             ┆ ---           ┆ ---           ┆ ---     │
# │ str           ┆ list[str]     ┆ i32    ┆ ---           ┆ str           ┆ list[str]     ┆ i32     │
# │               ┆               ┆        ┆ list[bool]    ┆               ┆               ┆         │
# ╞═══════════════╪═══════════════╪════════╪═══════════════╪═══════════════╪═══════════════╪═════════╡
# │ 93 NORTH 9TH  ┆ ["93",        ┆ 93     ┆ [false,       ┆ NORTH 9TH     ┆ ["BROOKLYN"]  ┆ 11211   │
# │ STREET,       ┆ "NORTH", …    ┆        ┆ false, …      ┆ STREET,       ┆               ┆         │
# │ BROOKLYN NY   ┆ "11211"]      ┆        ┆ false]        ┆               ┆               ┆         │
# │ 11211         ┆               ┆        ┆               ┆               ┆               ┆         │
# │ 380           ┆ ["380", "WEST ┆ 380    ┆ [false,       ┆ WESTMINSTER   ┆ ["PROVIDENCE" ┆ 2903    │
# │ WESTMINSTER   ┆ MINSTER", …   ┆        ┆ false, …      ┆ ST,           ┆ ]             ┆         │
# │ ST,           ┆ "02903"]      ┆        ┆ false]        ┆               ┆               ┆         │
# │ PROVIDENCE RI ┆               ┆        ┆               ┆               ┆               ┆         │
# │ 02903         ┆               ┆        ┆               ┆               ┆               ┆         │
# │ 177 MAIN      ┆ ["177",       ┆ 177    ┆ [false,       ┆ MAIN STREET,  ┆ ["LITTLETON"] ┆ 3561    │
# │ STREET,       ┆ "MAIN", …     ┆        ┆ false, …      ┆               ┆               ┆         │
# │ LITTLETON NH  ┆ "03561"]      ┆        ┆ false]        ┆               ┆               ┆         │
# │ 03561         ┆               ┆        ┆               ┆               ┆               ┆         │
# └───────────────┴───────────────┴────────┴───────────────┴───────────────┴───────────────┴─────────┘

# %% [markdown]
# ### Exercise 2

# %%
pl.Config.set_fmt_str_lengths(100)

pl.Config.set_tbl_rows(10)

spotify_csv = "data/spotify-charts-2017-2021-global-top200.csv.gz"
spotify_df = pl.read_csv(spotify_csv,try_parse_dates=True)
spotify_df.head(3)
# Out:
# shape: (3, 9)
# ┌───────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬──────────────┬─────────┐
# │ title         ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend        ┆ streams │
# │ ---           ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---          ┆ ---     │
# │ str           ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str          ┆ i64     │
# ╞═══════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪══════════════╪═════════╡
# │ Starboy       ┆ 1    ┆ 2017-01-01 ┆ The Weeknd,   ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3135625 │
# │               ┆      ┆            ┆ Daft Punk     ┆   ┆        ┆        ┆ N            ┆         │
# │ Closer        ┆ 2    ┆ 2017-01-01 ┆ The           ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3015525 │
# │               ┆      ┆            ┆ Chainsmokers, ┆   ┆        ┆        ┆ N            ┆         │
# │               ┆      ┆            ┆ Halsey        ┆   ┆        ┆        ┆              ┆         │
# │ Let Me Love   ┆ 3    ┆ 2017-01-01 ┆ DJ Snake,     ┆ … ┆ Global ┆ top200 ┆ MOVE_UP      ┆ 2545384 │
# │ You           ┆      ┆            ┆ Justin Bieber ┆   ┆        ┆        ┆              ┆         │
# └───────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴──────────────┴─────────┘

# %% [markdown]
# - Keep one row for each unique track (with uniqueness defined by the title and artist columns)
# - Create a list column called `artists` by splitting the `artist` column

# %%
spotify_df\
.unique(["title", "artist"])\
.with_columns(
    pl.col("artist").str.split(" ").alias("artists")
)\
.select(
    "title","rank","date","artist","artists","streams"
).head(3)
# Out:
# shape: (3, 6)
# ┌───────────────────────────────┬──────┬────────────┬──────────────┬─────────────────────┬─────────┐
# │ title                         ┆ rank ┆ date       ┆ artist       ┆ artists             ┆ streams │
# │ ---                           ┆ ---  ┆ ---        ┆ ---          ┆ ---                 ┆ ---     │
# │ str                           ┆ i64  ┆ date       ┆ str          ┆ list[str]           ┆ i64     │
# ╞═══════════════════════════════╪══════╪════════════╪══════════════╪═════════════════════╪═════════╡
# │ Ich darf das                  ┆ 150  ┆ 2021-05-14 ┆ Shirin David ┆ ["Shirin", "David"] ┆ 888942  │
# │ Another One Bites The Dust -  ┆ 197  ┆ 2020-05-02 ┆ Queen        ┆ ["Queen"]           ┆ 635158  │
# │ Remastered 2011               ┆      ┆            ┆              ┆                     ┆         │
# │ Finesse                       ┆ 37   ┆ 2018-07-01 ┆ Drake        ┆ ["Drake"]           ┆ 1952491 │
# └───────────────────────────────┴──────┴────────────┴──────────────┴─────────────────────┴─────────┘

# %% [markdown]
# Continue by finding the 10 tracks with the most number of artists

# %%
spotify_df\
.unique(["title", "artist"])\
.with_columns(
    pl.col("artist").str.split(" ").alias("artists")
)\
.select(
    "title","rank","date","artist","artists","streams"
)\
.top_k(
    k=10,
    by=pl.col("artists").list.len()
)
# Out:
# shape: (10, 6)
# ┌─────────────────┬──────┬────────────┬─────────────────────────┬────────────────────────┬─────────┐
# │ title           ┆ rank ┆ date       ┆ artist                  ┆ artists                ┆ streams │
# │ ---             ┆ ---  ┆ ---        ┆ ---                     ┆ ---                    ┆ ---     │
# │ str             ┆ i64  ┆ date       ┆ str                     ┆ list[str]              ┆ i64     │
# ╞═════════════════╪══════╪════════════╪═════════════════════════╪════════════════════════╪═════════╡
# │ Susamam         ┆ 139  ┆ 2019-09-06 ┆ Şanışer, Kamufle, Mert  ┆ ["Şanışer,",           ┆ 825680  │
# │                 ┆      ┆            ┆ Şenel, Mirac, Aga B,    ┆ "Kamufle,", … "Fuat"]  ┆         │
# │                 ┆      ┆            ┆ Defkhan, Aspova, Yeis   ┆                        ┆         │
# │                 ┆      ┆            ┆ Sensura, Sehabe, Deniz  ┆                        ┆         │
# │                 ┆      ┆            ┆ Tekin, Ozbi…            ┆                        ┆         │
# │ Pa' La Cultura  ┆ 151  ┆ 2020-08-07 ┆ David Guetta, HUMAN(X), ┆ ["David", "Guetta,", … ┆ 808568  │
# │                 ┆      ┆            ┆ Sofía Reyes, Abraham    ┆ "Maejor"]              ┆         │
# │                 ┆      ┆            ┆ Mateo, De La Ghetto,    ┆                        ┆         │
# │                 ┆      ┆            ┆ Manuel Turizo, Zion &   ┆                        ┆         │
# │                 ┆      ┆            ┆ Lennox, Lalo…           ┆                        ┆         │
# │ Instagram       ┆ 99   ┆ 2019-07-05 ┆ Dimitri Vegas & Like    ┆ ["Dimitri", "Vegas", … ┆ 1031732 │
# │                 ┆      ┆            ┆ Mike, David Guetta,     ┆ "Mike"]                ┆         │
# │                 ┆      ┆            ┆ Daddy Yankee, Afro      ┆                        ┆         │
# │                 ┆      ┆            ┆ Bros, Natti Natasha,    ┆                        ┆         │
# │                 ┆      ┆            ┆ Dimitri Vegas, Like…    ┆                        ┆         │
# │ Quizás          ┆ 75   ┆ 2019-10-01 ┆ Rich Music LTD, Dalex,  ┆ ["Rich", "Music", …    ┆ 1042822 │
# │                 ┆      ┆            ┆ Sech, Justin Quiles,    ┆ "Feid"]                ┆         │
# │                 ┆      ┆            ┆ Wisin, Zion, Dímelo     ┆                        ┆         │
# │                 ┆      ┆            ┆ Flow, Lenny Tavárez,    ┆                        ┆         │
# │                 ┆      ┆            ┆ Feid                    ┆                        ┆         │
# │ Enséñame        ┆ 192  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce       ┆ ["RBD,", "Anahí,", …   ┆ 737990  │
# │                 ┆      ┆            ┆ María, Maite Perroni,   ┆ "Herrera"]             ┆         │
# │                 ┆      ┆            ┆ Christian Chávez,       ┆                        ┆         │
# │                 ┆      ┆            ┆ Christopher von         ┆                        ┆         │
# │                 ┆      ┆            ┆ Uckermann, Alfonso      ┆                        ┆         │
# │                 ┆      ┆            ┆ Herrera                 ┆                        ┆         │
# │ Aún Hay Algo    ┆ 195  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce       ┆ ["RBD,", "Anahí,", …   ┆ 735311  │
# │                 ┆      ┆            ┆ María, Maite Perroni,   ┆ "Herrera"]             ┆         │
# │                 ┆      ┆            ┆ Christian Chávez,       ┆                        ┆         │
# │                 ┆      ┆            ┆ Christopher von         ┆                        ┆         │
# │                 ┆      ┆            ┆ Uckermann, Alfonso      ┆                        ┆         │
# │                 ┆      ┆            ┆ Herrera                 ┆                        ┆         │
# │ Poblado - Remix ┆ 37   ┆ 2021-07-01 ┆ J Balvin, KAROL G,      ┆ ["J", "Balvin,", …     ┆ 1817017 │
# │                 ┆      ┆            ┆ Nicky Jam, Crissin,     ┆ "Shander"]             ┆         │
# │                 ┆      ┆            ┆ Totoy El Frio, Natan &  ┆                        ┆         │
# │                 ┆      ┆            ┆ Shander                 ┆                        ┆         │
# │ Rebelde         ┆ 130  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce       ┆ ["RBD,", "Anahí,", …   ┆ 882187  │
# │                 ┆      ┆            ┆ María, Maite Perroni,   ┆ "Herrera"]             ┆         │
# │                 ┆      ┆            ┆ Christian Chávez,       ┆                        ┆         │
# │                 ┆      ┆            ┆ Christopher von         ┆                        ┆         │
# │                 ┆      ┆            ┆ Uckermann, Alfonso      ┆                        ┆         │
# │                 ┆      ┆            ┆ Herrera                 ┆                        ┆         │
# │ Solo Quédate En ┆ 124  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce       ┆ ["RBD,", "Anahí,", …   ┆ 906122  │
# │ Silencio        ┆      ┆            ┆ María, Maite Perroni,   ┆ "Herrera"]             ┆         │
# │                 ┆      ┆            ┆ Christian Chávez,       ┆                        ┆         │
# │                 ┆      ┆            ┆ Christopher von         ┆                        ┆         │
# │                 ┆      ┆            ┆ Uckermann, Alfonso      ┆                        ┆         │
# │                 ┆      ┆            ┆ Herrera                 ┆                        ┆         │
# │ Nuestro Amor    ┆ 138  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce       ┆ ["RBD,", "Anahí,", …   ┆ 845060  │
# │                 ┆      ┆            ┆ María, Maite Perroni,   ┆ "Herrera"]             ┆         │
# │                 ┆      ┆            ┆ Christian Chávez,       ┆                        ┆         │
# │                 ┆      ┆            ┆ Christopher von         ┆                        ┆         │
# │                 ┆      ┆            ┆ Uckermann, Alfonso      ┆                        ┆         │
# │                 ┆      ┆            ┆ Herrera                 ┆                        ┆         │
# └─────────────────┴──────┴────────────┴─────────────────────────┴────────────────────────┴─────────┘

# %% [markdown]
# Apply a `pl.Config` setting to ensure we can read all of the list elements and then display the results again

# %%
pl.Config.set_fmt_table_cell_list_len(50)
# Out:
# polars.config.Config

# %%
spotify_df\
.unique(["title", "artist"])\
.with_columns(
    pl.col("artist").str.split(" ").alias("artists")
)\
.select(
    "title","rank","date","artist","artists","streams"
)\
.top_k(
    k=10,
    by=pl.col("artists").list.len()
)
# Out:
# shape: (10, 6)
# ┌──────────────────────┬──────┬────────────┬──────────────────────┬──────────────────────┬─────────┐
# │ title                ┆ rank ┆ date       ┆ artist               ┆ artists              ┆ streams │
# │ ---                  ┆ ---  ┆ ---        ┆ ---                  ┆ ---                  ┆ ---     │
# │ str                  ┆ i64  ┆ date       ┆ str                  ┆ list[str]            ┆ i64     │
# ╞══════════════════════╪══════╪════════════╪══════════════════════╪══════════════════════╪═════════╡
# │ Susamam              ┆ 139  ┆ 2019-09-06 ┆ Şanışer, Kamufle,    ┆ ["Şanışer,",         ┆ 825680  │
# │                      ┆      ┆            ┆ Mert Şenel, Mirac,   ┆ "Kamufle,", "Mert",  ┆         │
# │                      ┆      ┆            ┆ Aga B, Defkhan,      ┆ "Şenel,", "Mirac,",  ┆         │
# │                      ┆      ┆            ┆ Aspova, Yeis         ┆ "Aga", "B,",         ┆         │
# │                      ┆      ┆            ┆ Sensura, Sehabe,     ┆ "Defkhan,",          ┆         │
# │                      ┆      ┆            ┆ Deniz Tekin, Ozbi…   ┆ "Aspova,", "Yeis",   ┆         │
# │                      ┆      ┆            ┆                      ┆ "Se…                 ┆         │
# │ Pa' La Cultura       ┆ 151  ┆ 2020-08-07 ┆ David Guetta,        ┆ ["David", "Guetta,", ┆ 808568  │
# │                      ┆      ┆            ┆ HUMAN(X), Sofía      ┆ "HUMAN(X),",         ┆         │
# │                      ┆      ┆            ┆ Reyes, Abraham       ┆ "Sofía", "Reyes,",   ┆         │
# │                      ┆      ┆            ┆ Mateo, De La Ghetto, ┆ "Abraham", "Mateo,", ┆         │
# │                      ┆      ┆            ┆ Manuel Turizo, Zion  ┆ "De", "La",          ┆         │
# │                      ┆      ┆            ┆ & Lennox, Lalo…      ┆ "Ghetto,", "Ma…      ┆         │
# │ Instagram            ┆ 99   ┆ 2019-07-05 ┆ Dimitri Vegas & Like ┆ ["Dimitri", "Vegas", ┆ 1031732 │
# │                      ┆      ┆            ┆ Mike, David Guetta,  ┆ "&", "Like",         ┆         │
# │                      ┆      ┆            ┆ Daddy Yankee, Afro   ┆ "Mike,", "David",    ┆         │
# │                      ┆      ┆            ┆ Bros, Natti Natasha, ┆ "Guetta,", "Daddy",  ┆         │
# │                      ┆      ┆            ┆ Dimitri Vegas, Like… ┆ "Yankee,", "Afro",   ┆         │
# │                      ┆      ┆            ┆                      ┆ "Bros,", …           ┆         │
# │ Quizás               ┆ 75   ┆ 2019-10-01 ┆ Rich Music LTD,      ┆ ["Rich", "Music",    ┆ 1042822 │
# │                      ┆      ┆            ┆ Dalex, Sech, Justin  ┆ "LTD,", "Dalex,",    ┆         │
# │                      ┆      ┆            ┆ Quiles, Wisin, Zion, ┆ "Sech,", "Justin",   ┆         │
# │                      ┆      ┆            ┆ Dímelo Flow, Lenny   ┆ "Quiles,", "Wisin,", ┆         │
# │                      ┆      ┆            ┆ Tavárez, Feid        ┆ "Zion,", "Dímelo",   ┆         │
# │                      ┆      ┆            ┆                      ┆ "Flow…               ┆         │
# │ Nuestro Amor         ┆ 138  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce    ┆ ["RBD,", "Anahí,",   ┆ 845060  │
# │                      ┆      ┆            ┆ María, Maite         ┆ "Dulce", "María,",   ┆         │
# │                      ┆      ┆            ┆ Perroni, Christian   ┆ "Maite", "Perroni,", ┆         │
# │                      ┆      ┆            ┆ Chávez, Christopher  ┆ "Christian",         ┆         │
# │                      ┆      ┆            ┆ von Uckermann,       ┆ "Chávez,",           ┆         │
# │                      ┆      ┆            ┆ Alfonso Herrera      ┆ "Christopher", "v…   ┆         │
# │ Sálvame              ┆ 110  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce    ┆ ["RBD,", "Anahí,",   ┆ 973935  │
# │                      ┆      ┆            ┆ María, Maite         ┆ "Dulce", "María,",   ┆         │
# │                      ┆      ┆            ┆ Perroni, Christian   ┆ "Maite", "Perroni,", ┆         │
# │                      ┆      ┆            ┆ Chávez, Christopher  ┆ "Christian",         ┆         │
# │                      ┆      ┆            ┆ von Uckermann,       ┆ "Chávez,",           ┆         │
# │                      ┆      ┆            ┆ Alfonso Herrera      ┆ "Christopher", "v…   ┆         │
# │ Travesuras - Remix   ┆ 85   ┆ 2021-04-01 ┆ Nio Garcia, Casper   ┆ ["Nio", "Garcia,",   ┆ 1057549 │
# │                      ┆      ┆            ┆ Magico, Ozuna, Wisin ┆ "Casper", "Magico,", ┆         │
# │                      ┆      ┆            ┆ & Yandel, Myke       ┆ "Ozuna,", "Wisin",   ┆         │
# │                      ┆      ┆            ┆ Towers, Flow La      ┆ "&", "Yandel,",      ┆         │
# │                      ┆      ┆            ┆ Movie                ┆ "Myke", "Towers,",   ┆         │
# │                      ┆      ┆            ┆                      ┆ "Flow"…              ┆         │
# │ Enséñame             ┆ 192  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce    ┆ ["RBD,", "Anahí,",   ┆ 737990  │
# │                      ┆      ┆            ┆ María, Maite         ┆ "Dulce", "María,",   ┆         │
# │                      ┆      ┆            ┆ Perroni, Christian   ┆ "Maite", "Perroni,", ┆         │
# │                      ┆      ┆            ┆ Chávez, Christopher  ┆ "Christian",         ┆         │
# │                      ┆      ┆            ┆ von Uckermann,       ┆ "Chávez,",           ┆         │
# │                      ┆      ┆            ┆ Alfonso Herrera      ┆ "Christopher", "v…   ┆         │
# │ Un Poco De Tu Amor   ┆ 185  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce    ┆ ["RBD,", "Anahí,",   ┆ 749396  │
# │                      ┆      ┆            ┆ María, Maite         ┆ "Dulce", "María,",   ┆         │
# │                      ┆      ┆            ┆ Perroni, Christian   ┆ "Maite", "Perroni,", ┆         │
# │                      ┆      ┆            ┆ Chávez, Christopher  ┆ "Christian",         ┆         │
# │                      ┆      ┆            ┆ von Uckermann,       ┆ "Chávez,",           ┆         │
# │                      ┆      ┆            ┆ Alfonso Herrera      ┆ "Christopher", "v…   ┆         │
# │ Solo Quédate En      ┆ 124  ┆ 2020-09-04 ┆ RBD, Anahí, Dulce    ┆ ["RBD,", "Anahí,",   ┆ 906122  │
# │ Silencio             ┆      ┆            ┆ María, Maite         ┆ "Dulce", "María,",   ┆         │
# │                      ┆      ┆            ┆ Perroni, Christian   ┆ "Maite", "Perroni,", ┆         │
# │                      ┆      ┆            ┆ Chávez, Christopher  ┆ "Christian",         ┆         │
# │                      ┆      ┆            ┆ von Uckermann,       ┆ "Chávez,",           ┆         │
# │                      ┆      ┆            ┆ Alfonso Herrera      ┆ "Christopher", "v…   ┆         │
# └──────────────────────┴──────┴────────────┴──────────────────────┴──────────────────────┴─────────┘

# %% [markdown]
# Create a new column called `lead_artist` with the first listed artist from each list.
#
# Return only the `title`,`artist` and `lead_artist` columns

# %%
spotify_df.select(
    "title", "artist", pl.col("artist").str.split(" ").list.first().alias("lead_artist")
)
# Out:
# shape: (362_182, 3)
# ┌─────────────────────────────────────────┬──────────────────────────┬─────────────┐
# │ title                                   ┆ artist                   ┆ lead_artist │
# │ ---                                     ┆ ---                      ┆ ---         │
# │ str                                     ┆ str                      ┆ str         │
# ╞═════════════════════════════════════════╪══════════════════════════╪═════════════╡
# │ Starboy                                 ┆ The Weeknd, Daft Punk    ┆ The         │
# │ Closer                                  ┆ The Chainsmokers, Halsey ┆ The         │
# │ Let Me Love You                         ┆ DJ Snake, Justin Bieber  ┆ DJ          │
# │ Rockabye (feat. Sean Paul & Anne-Marie) ┆ Clean Bandit             ┆ Clean       │
# │ One Dance                               ┆ Drake, WizKid, Kyla      ┆ Drake,      │
# │ …                                       ┆ …                        ┆ …           │
# │ Slow Hands                              ┆ Niall Horan              ┆ Niall       │
# │ New Freezer (feat. Kendrick Lamar)      ┆ Rich The Kid             ┆ Rich        │
# │ Explícale (feat. Bad Bunny)             ┆ Yandel                   ┆ Yandel      │
# │ The Scientist                           ┆ Coldplay                 ┆ Coldplay    │
# │ Stay With Me                            ┆ Sam Smith                ┆ Sam         │
# └─────────────────────────────────────────┴──────────────────────────┴─────────────┘

# %% [markdown]
# Get the top 10 artists ranked by their maximum number of streams for a track
# - Explode the `artists` list column so each artist is on their own row
# - Group by the exploded artists
# - Aggregate to get the maximum of the `streams`

# %%
spotify_df\
.with_columns(
    artists = pl.col("artist").str.split(",")
)\
.select("artists", "streams")\
.explode("artists")\
.group_by("artists")\
.agg(
    pl.col("streams").max()
)\
.top_k(
    k=10,
    by="streams"
)
# Out:
# shape: (10, 2)
# ┌────────────────┬──────────┐
# │ artists        ┆ streams  │
# │ ---            ┆ ---      │
# │ str            ┆ i64      │
# ╞════════════════╪══════════╡
# │ Adele          ┆ 19749704 │
# │ Mariah Carey   ┆ 17223237 │
# │ Wham!          ┆ 15813799 │
# │ Olivia Rodrigo ┆ 13714177 │
# │ Drake          ┆ 12384750 │
# │ Ariana Grande  ┆ 12229331 │
# │ Michael Bublé  ┆ 11975033 │
# │ Bobby Helms    ┆ 11924353 │
# │ Brenda Lee     ┆ 11801426 │
# │ Luis Fonsi     ┆ 11381520 │
# └────────────────┴──────────┘
