# %% [markdown]
# # Data Types

# %%
import polars as pl

# %%
csv_file = "data/titanic.csv"

# %%
df = pl.read_csv(csv_file)
df.head()
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# ...

# %% [markdown]
# ## Data Type Schema
#
# `.schema` attribute shows the dtype of every columns.

# %%
df.schema
# Out:
# Schema([('PassengerId', Int64),
#         ('Survived', Int64),
#         ('Pclass', Int64),
#         ('Name', String),
#         ('Sex', String),
#         ('Age', Float64),
#         ('SibSp', Int64),
#         ('Parch', Int64),
#         ('Ticket', String),
#         ('Fare', Float64),
#         ('Cabin', String),
#         ('Embarked', String)])

# %% [markdown]
# `.dtypes` can display the data type as well, but it excludes column names.

# %%
df.dtypes
# Out:
# [Int64,
#  Int64,
#  Int64,
#  String,
#  String,
#  Float64,
#  Int64,
#  Int64,
#  String,
#  Float64,
#  String,
#  String]

# %% [markdown]
# A `Series` also has a data type attribute

# %%
df["Age"].dtype
# Out:
# Float64
