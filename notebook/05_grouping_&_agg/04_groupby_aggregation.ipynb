# %% [markdown]
# # Group iteration and aggregations

# %%
import polars as pl
import polars.selectors as cs

# %%
csv_file = 'data/titanic.csv'

# %%
df = pl.read_csv(csv_file)
df.head(3)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %% [markdown]
# ## Iterating over groups
#
# The group key is a `tuple` even when we are only grouping by one column.

# %%
for (pclass,), group_df in df.group_by("Pclass"): # group_df is the rest columns
    print(f"Pclass: {pclass}")
    print(group_df.mean())
# Out:
# Pclass: 1
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 461.597222  ┆ 0.62963  ┆ 1.0    ┆ null ┆ … ┆ null   ┆ 84.154688 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 2
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 445.956522  ┆ 0.472826 ┆ 2.0    ┆ null ┆ … ┆ null   ┆ 20.662183 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 3
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬──────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare     ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---      ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64      ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪══════════╪═══════╪══════════╡
# │ 439.154786  ┆ 0.242363 ┆ 3.0    ┆ null ┆ … ┆ null   ┆ 13.67555 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴──────────┴───────┴──────────┘

# %% [markdown]
# When grouping by multiple columns, the first element as a `tuple` naturally extends to multiple group keys

# %%
for (pclass,survived), group_df in df.group_by("Pclass", "Survived"):
    print(f"Pclass: {pclass}, Survived: {survived}")
    print(group_df.mean())
# Out:
# Pclass: 1, Survived: 0
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 410.3       ┆ 0.0      ┆ 1.0    ┆ null ┆ … ┆ null   ┆ 64.684008 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 2, Survived: 1
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---     ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═════════╪═══════╪══════════╡
# │ 439.08046   ┆ 1.0      ┆ 2.0    ┆ null ┆ … ┆ null   ┆ 22.0557 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴─────────┴───────┴──────────┘
# Pclass: 3, Survived: 1
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 394.058824  ┆ 1.0      ┆ 3.0    ┆ null ┆ … ┆ null   ┆ 13.694887 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 2, Survived: 0
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 452.123711  ┆ 0.0      ┆ 2.0    ┆ null ┆ … ┆ null   ┆ 19.412328 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 1, Survived: 1
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 491.772059  ┆ 1.0      ┆ 1.0    ┆ null ┆ … ┆ null   ┆ 95.608029 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘
# Pclass: 3, Survived: 0
# shape: (1, 12)
# ┌─────────────┬──────────┬────────┬──────┬───┬────────┬───────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name ┆ … ┆ Ticket ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---  ┆   ┆ ---    ┆ ---       ┆ ---   ┆ ---      │
# │ f64         ┆ f64      ┆ f64    ┆ str  ┆   ┆ str    ┆ f64       ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════╪═══╪════════╪═══════════╪═══════╪══════════╡
# │ 453.580645  ┆ 0.0      ┆ 3.0    ┆ null ┆ … ┆ null   ┆ 13.669364 ┆ null  ┆ null     │
# └─────────────┴──────────┴────────┴──────┴───┴────────┴───────────┴───────┴──────────┘

# %% [markdown]
# ## Group values
# We use `head` to get the first rows in each group.
#
# > **Note** The returned rows depending on how many groups we have.

# %%
df.group_by("Pclass").head(2)
# Out:
# shape: (6, 12)
# ┌────────┬─────────────┬──────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ Pclass ┆ PassengerId ┆ Survived ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---    ┆ ---         ┆ ---      ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64    ┆ i64         ┆ i64      ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞════════╪═════════════╪══════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 2      ┆ 10          ┆ 1        ┆ Nasser, Mrs.      ┆ … ┆ 237736    ┆ 30.0708 ┆ null  ┆ C        │
# │        ┆             ┆          ┆ Nicholas (Adele   ┆   ┆           ┆         ┆       ┆          │
# │        ┆             ┆          ┆ A…                ┆   ┆           ┆         ┆       ┆          │
# │ 2      ┆ 16          ┆ 1        ┆ Hewlett, Mrs.     ┆ … ┆ 248706    ┆ 16.0    ┆ null  ┆ S        │
# │        ┆             ┆          ┆ (Mary D Kingcome… ┆   ┆           ┆         ┆       ┆          │
# │ 1      ┆ 2           ┆ 1        ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │        ┆             ┆          ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 1      ┆ 4           ┆ 1        ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │        ┆             ┆          ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 3      ┆ 1           ┆ 0        ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │        ┆             ┆          ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 3      ┆ 3           ┆ 1        ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │        ┆             ┆          ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# └────────┴─────────────┴──────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %% [markdown]
# ## Calling aggregations directly on `group_by`

# %%
df.group_by("Pclass").len() # Calculate the count
# Out:
# shape: (3, 2)
# ┌────────┬─────┐
# │ Pclass ┆ len │
# │ ---    ┆ --- │
# │ i64    ┆ u32 │
# ╞════════╪═════╡
# │ 1      ┆ 216 │
# │ 3      ┆ 491 │
# │ 2      ┆ 184 │
# └────────┴─────┘

# %% [markdown]
# The methods we can all on `GroupBy` include:
#  - `first` get the first element of each group
#  - `last` get the last element of each group
#  - `n_unique` get the number of unique elements in each group
#  - `count` get the number of elements in each group
#  - `sum` sum the elements in each group
#  - `min` get the smallest element in each group
#  - `max` get the largest element in each group
#  - `mean` get the average of elements in each group
#  - `median` get the median in each group
#  - `quantile` calculate quantiles in each group
#
# We can also call aggregations on a lazy group though not all of the above are supported

# %% [markdown]
# ## Multiple aggregations on the same columns

# %%
group_column = "Pclass"

df.group_by(group_column)\
.agg(
    pl.col(pl.Float64).min().name.suffix("_min"),
    pl.col(pl.Float64).max().name.suffix("_max"),
)\
.pipe(
    lambda df: df.select(
        [group_column] + sorted(df.columns[1:])
    )
)
# Out:
# shape: (3, 5)
# ┌────────┬─────────┬─────────┬──────────┬──────────┐
# │ Pclass ┆ Age_max ┆ Age_min ┆ Fare_max ┆ Fare_min │
# │ ---    ┆ ---     ┆ ---     ┆ ---      ┆ ---      │
# │ i64    ┆ f64     ┆ f64     ┆ f64      ┆ f64      │
# ╞════════╪═════════╪═════════╪══════════╪══════════╡
# │ 3      ┆ 74.0    ┆ 0.42    ┆ 69.55    ┆ 0.0      │
# │ 1      ┆ 80.0    ┆ 0.92    ┆ 512.3292 ┆ 0.0      │
# │ 2      ┆ 70.0    ┆ 0.67    ┆ 73.5     ┆ 0.0      │
# └────────┴─────────┴─────────┴──────────┴──────────┘

# %% [markdown]
# Use `Selector API`

# %%
group_column = "Pclass"

df.group_by(group_column)\
.agg(
    cs.float().min().name.suffix("_min"),
    cs.float().max().name.suffix("_max"),
)\
.pipe(
    lambda df: df.select(
        [group_column] + sorted(df.columns[1:])
    )
)
# Out:
# shape: (3, 5)
# ┌────────┬─────────┬─────────┬──────────┬──────────┐
# │ Pclass ┆ Age_max ┆ Age_min ┆ Fare_max ┆ Fare_min │
# │ ---    ┆ ---     ┆ ---     ┆ ---      ┆ ---      │
# │ i64    ┆ f64     ┆ f64     ┆ f64      ┆ f64      │
# ╞════════╪═════════╪═════════╪══════════╪══════════╡
# │ 1      ┆ 80.0    ┆ 0.92    ┆ 512.3292 ┆ 0.0      │
# │ 2      ┆ 70.0    ┆ 0.67    ┆ 73.5     ┆ 0.0      │
# │ 3      ┆ 74.0    ┆ 0.42    ┆ 69.55    ┆ 0.0      │
# └────────┴─────────┴─────────┴──────────┴──────────┘

# %% [markdown]
# ## User-defined functions on groups
# We can define user-defined functions on groups with `map_groups`.

# %%
df.group_by("Pclass")\
.map_groups(
    lambda group_df: group_df.max()
)
# Out:
# shape: (3, 12)
# ┌─────────────┬──────────┬────────┬─────────────────┬───┬────────────┬──────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name            ┆ … ┆ Ticket     ┆ Fare     ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---             ┆   ┆ ---        ┆ ---      ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str             ┆   ┆ str        ┆ f64      ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═════════════════╪═══╪════════════╪══════════╪═══════╪══════════╡
# │ 887         ┆ 1        ┆ 2      ┆ del Carlo, Mr.  ┆ … ┆ W/C 14208  ┆ 73.5     ┆ F4    ┆ S        │
# │             ┆          ┆        ┆ Sebastiano      ┆   ┆            ┆          ┆       ┆          │
# │ 891         ┆ 1        ┆ 3      ┆ van Melkebeke,  ┆ … ┆ W./C. 6609 ┆ 69.55    ┆ G6    ┆ S        │
# │             ┆          ┆        ┆ Mr. Philemon    ┆   ┆            ┆          ┆       ┆          │
# │ 890         ┆ 1        ┆ 1      ┆ Young, Miss.    ┆ … ┆ WE/P 5735  ┆ 512.3292 ┆ T     ┆ S        │
# │             ┆          ┆        ┆ Marie Grice     ┆   ┆            ┆          ┆       ┆          │
# └─────────────┴──────────┴────────┴─────────────────┴───┴────────────┴──────────┴───────┴──────────┘

# %%
df.group_by("Pclass")\
.map_groups(
    lambda group_df: group_df.select(pl.col(pl.Float64)).head(2)
)
# Out:
# shape: (6, 2)
# ┌──────┬─────────┐
# │ Age  ┆ Fare    │
# │ ---  ┆ ---     │
# │ f64  ┆ f64     │
# ╞══════╪═════════╡
# │ 38.0 ┆ 71.2833 │
# │ 35.0 ┆ 53.1    │
# │ 22.0 ┆ 7.25    │
# │ 26.0 ┆ 7.925   │
# │ 14.0 ┆ 30.0708 │
# │ 55.0 ┆ 16.0    │
# └──────┴─────────┘

# %% [markdown]
# > The UDF in Polars will break the select optimizer, hence, using the built-in Polars function in advanced.

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# Group by the `Pclass` column.
#
# Count the number of passengers in each group without using `agg`

# %%
df.group_by("Pclass").len()
# Out:
# shape: (3, 2)
# ┌────────┬─────┐
# │ Pclass ┆ len │
# │ ---    ┆ --- │
# │ i64    ┆ u32 │
# ╞════════╪═════╡
# │ 1      ┆ 216 │
# │ 3      ┆ 491 │
# │ 2      ┆ 184 │
# └────────┴─────┘

# %% [markdown]
# Add a column called `percent` with the percentage of the total passengers in each group

# %%
df.group_by("Pclass").len()\
.with_columns(
    percent = ((pl.col("len") / pl.col("len").sum()) *100)
)
# Out:
# shape: (3, 3)
# ┌────────┬─────┬───────────┐
# │ Pclass ┆ len ┆ percent   │
# │ ---    ┆ --- ┆ ---       │
# │ i64    ┆ u32 ┆ f64       │
# ╞════════╪═════╪═══════════╡
# │ 2      ┆ 184 ┆ 20.650954 │
# │ 3      ┆ 491 ┆ 55.106622 │
# │ 1      ┆ 216 ┆ 24.242424 │
# └────────┴─────┴───────────┘

# %% [markdown]
# Create a bar chart of the `percent` column with the title `% per class"`

# %%
df.group_by("Pclass").len()\
.with_columns(
    pl.col("Pclass").cast(pl.Utf8),
    percent = ((pl.col("len") / pl.col("len").sum()) *100)
)\
.plot\
.bar(
    x="Pclass",
    y="percent",
    color="Pclass"
)\
.properties(title="% per class", width=500)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Exercise 2
# Create a `DataFrame` from the Spotify data

# %%
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_tbl_rows(10)
spotify_csv = "data/spotify-charts-2017-2021-global-top200.csv.gz"
spotify_df = pl.read_csv(spotify_csv,try_parse_dates=True)
spotify_df.head(3)
# Out:
# shape: (3, 9)
# ┌───────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬──────────────┬─────────┐
# │ title         ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend        ┆ streams │
# │ ---           ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---          ┆ ---     │
# │ str           ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str          ┆ i64     │
# ╞═══════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪══════════════╪═════════╡
# │ Starboy       ┆ 1    ┆ 2017-01-01 ┆ The Weeknd,   ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3135625 │
# │               ┆      ┆            ┆ Daft Punk     ┆   ┆        ┆        ┆ N            ┆         │
# │ Closer        ┆ 2    ┆ 2017-01-01 ┆ The           ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 3015525 │
# │               ┆      ┆            ┆ Chainsmokers, ┆   ┆        ┆        ┆ N            ┆         │
# │               ┆      ┆            ┆ Halsey        ┆   ┆        ┆        ┆              ┆         │
# │ Let Me Love   ┆ 3    ┆ 2017-01-01 ┆ DJ Snake,     ┆ … ┆ Global ┆ top200 ┆ MOVE_UP      ┆ 2545384 │
# │ You           ┆      ┆            ┆ Justin Bieber ┆   ┆        ┆        ┆              ┆         │
# └───────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴──────────────┴─────────┘

# %% [markdown]
# We want to inspect some data for the top-streaming artists by printing it out:
# - filter `spotify_df` to include only rows that had more than 10 million streams
# - `group_by` the `artist` column
# - ensure the order of the output is the same each time
# - print the `artist` key
# - print the sub-`DataFrame`

# %%
for (artist,), artist_df in (
    spotify_df.filter(
        pl.col("streams") > 10_000_000
    ).group_by(
        "artist", maintain_order=True
    )
):
    print(artist)
    print(artist_df)
# Out:
# XXXTENTACION
# shape: (1, 9)
# ┌───────┬──────┬────────────┬──────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title ┆ rank ┆ date       ┆ artist       ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---   ┆ ---  ┆ ---        ┆ ---          ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str   ┆ i64  ┆ date       ┆ str          ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞═══════╪══════╪════════════╪══════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ SAD!  ┆ 1    ┆ 2018-06-19 ┆ XXXTENTACION ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10415088 │
# └───────┴──────┴────────────┴──────────────┴───┴────────┴────────┴─────────┴──────────┘
# Ariana Grande
# shape: (2, 9)
# ┌──────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬─────────────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend           ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---             ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str             ┆ i64      │
# ╞══════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═════════════════╪══════════╡
# │ 7 rings          ┆ 1    ┆ 2019-02-08 ┆ Ariana ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10445538 │
# │                  ┆      ┆            ┆ Grande ┆   ┆        ┆        ┆                 ┆          │
# │ Santa Tell Me    ┆ 3    ┆ 2020-12-24 ┆ Ariana ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 12229331 │
# │                  ┆      ┆            ┆ Grande ┆   ┆        ┆        ┆                 ┆          │
# └──────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴─────────────────┴──────────┘
# Ed Sheeran
# shape: (1, 9)
# ┌────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title              ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ I Don't Care (with ┆ 1    ┆ 2019-05-10 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 10977389 │
# │ Justin Bieber)     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# └────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴───────────┴──────────┘
# Mariah Carey
# shape: (4, 9)
# ┌───────────────┬──────┬────────────┬──────────────┬───┬────────┬────────┬──────────────┬──────────┐
# │ title         ┆ rank ┆ date       ┆ artist       ┆ … ┆ region ┆ chart  ┆ trend        ┆ streams  │
# │ ---           ┆ ---  ┆ ---        ┆ ---          ┆   ┆ ---    ┆ ---    ┆ ---          ┆ ---      │
# │ str           ┆ i64  ┆ date       ┆ str          ┆   ┆ str    ┆ str    ┆ str          ┆ i64      │
# ╞═══════════════╪══════╪════════════╪══════════════╪═══╪════════╪════════╪══════════════╪══════════╡
# │ All I Want    ┆ 1    ┆ 2018-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 10819009 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2019-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ MOVE_UP      ┆ 12028987 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2020-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 17223237 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2020-12-25 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 13573228 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# └───────────────┴──────┴────────────┴──────────────┴───┴────────┴────────┴──────────────┴──────────┘
# Wham!
# shape: (3, 9)
# ┌────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title          ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---            ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str            ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ Last Christmas ┆ 2    ┆ 2019-12-24 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 10069590 │
# │ Last Christmas ┆ 2    ┆ 2020-12-24 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 15813799 │
# │ Last Christmas ┆ 2    ┆ 2020-12-25 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 12415012 │
# └────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────────┴──────────┘
# Luis Fonsi
# shape: (1, 9)
# ┌──────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title                ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---                  ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str                  ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞══════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ Despacito (Featuring ┆ 1    ┆ 2017-05-27 ┆ Luis Fonsi ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 11381520 │
# │ Daddy Yankee)        ┆      ┆            ┆            ┆   ┆        ┆        ┆         ┆          │
# └──────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴─────────┴──────────┘
# Olivia Rodrigo
# shape: (28, 9)
# ┌──────────┬──────┬────────────┬─────────────────┬───┬────────┬────────┬────────────────┬──────────┐
# │ title    ┆ rank ┆ date       ┆ artist          ┆ … ┆ region ┆ chart  ┆ trend          ┆ streams  │
# │ ---      ┆ ---  ┆ ---        ┆ ---             ┆   ┆ ---    ┆ ---    ┆ ---            ┆ ---      │
# │ str      ┆ i64  ┆ date       ┆ str             ┆   ┆ str    ┆ str    ┆ str            ┆ i64      │
# ╞══════════╪══════╪════════════╪═════════════════╪═══╪════════╪════════╪════════════════╪══════════╡
# │ drivers  ┆ 1    ┆ 2021-01-11 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 11510867 │
# │ license  ┆      ┆            ┆                 ┆   ┆        ┆        ┆                ┆          │
# │ drivers  ┆ 1    ┆ 2021-01-12 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 13412192 │
# │ license  ┆      ┆            ┆                 ┆   ┆        ┆        ┆                ┆          │
# │ drivers  ┆ 1    ┆ 2021-01-13 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 13628143 │
# │ license  ┆      ┆            ┆                 ┆   ┆        ┆        ┆                ┆          │
# │ drivers  ┆ 1    ┆ 2021-01-14 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 13701177 │
# │ license  ┆      ┆            ┆                 ┆   ┆        ┆        ┆                ┆          │
# │ drivers  ┆ 1    ┆ 2021-01-15 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 13714177 │
# │ license  ┆      ┆            ┆                 ┆   ┆        ┆        ┆                ┆          │
# │ …        ┆ …    ┆ …          ┆ …               ┆ … ┆ …      ┆ …      ┆ …              ┆ …        │
# │ good 4 u ┆ 1    ┆ 2021-05-27 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 12292053 │
# │ good 4 u ┆ 1    ┆ 2021-05-28 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 11768671 │
# │ good 4 u ┆ 1    ┆ 2021-05-29 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 11365323 │
# │ good 4 u ┆ 1    ┆ 2021-05-30 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 10251400 │
# │ good 4 u ┆ 1    ┆ 2021-05-31 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION  ┆ 10827936 │
# └──────────┴──────┴────────────┴─────────────────┴───┴────────┴────────┴────────────────┴──────────┘
# Michael Bublé
# shape: (2, 9)
# ┌─────────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title           ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---             ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str             ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞═════════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ It's Beginning  ┆ 4    ┆ 2020-12-24 ┆ Michael Bublé ┆ … ┆ Global ┆ top200 ┆ MOVE_UP   ┆ 11975033 │
# │ to Look a Lot   ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ like Christmas  ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ It's Beginning  ┆ 5    ┆ 2020-12-25 ┆ Michael Bublé ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN ┆ 10023249 │
# │ to Look a Lot   ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ like Christmas  ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# └─────────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴───────────┴──────────┘
# Bobby Helms
# shape: (2, 9)
# ┌──────────────────┬──────┬────────────┬─────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist      ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---         ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str         ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞══════════════════╪══════╪════════════╪═════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ Jingle Bell Rock ┆ 5    ┆ 2020-12-24 ┆ Bobby Helms ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 11924353 │
# │ Jingle Bell Rock ┆ 4    ┆ 2020-12-25 ┆ Bobby Helms ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10680793 │
# └──────────────────┴──────┴────────────┴─────────────┴───┴────────┴────────┴─────────┴──────────┘
# Brenda Lee
# shape: (2, 9)
# ┌────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title              ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Rockin' Around The ┆ 6    ┆ 2020-12-24 ┆ Brenda Lee ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN ┆ 11801426 │
# │ Christmas Tree     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# │ Rockin' Around The ┆ 3    ┆ 2020-12-25 ┆ Brenda Lee ┆ … ┆ Global ┆ top200 ┆ MOVE_UP   ┆ 10893485 │
# │ Christmas Tree     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# └────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴───────────┴──────────┘
# Andy Williams
# shape: (1, 9)
# ┌───────────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title             ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---               ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str               ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞═══════════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ It's the Most     ┆ 7    ┆ 2020-12-24 ┆ Andy Williams ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10429582 │
# │ Wonderful Time of ┆      ┆            ┆               ┆   ┆        ┆        ┆         ┆          │
# │ the Year          ┆      ┆            ┆               ┆   ┆        ┆        ┆         ┆          │
# └───────────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴─────────┴──────────┘
# Bad Bunny, Jhay Cortez
# shape: (1, 9)
# ┌────────┬──────┬────────────┬─────────────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title  ┆ rank ┆ date       ┆ artist          ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---    ┆ ---  ┆ ---        ┆ ---             ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str    ┆ i64  ┆ date       ┆ str             ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════╪══════╪════════════╪═════════════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ DÁKITI ┆ 1    ┆ 2020-11-27 ┆ Bad Bunny, Jhay ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10086143 │
# │        ┆      ┆            ┆ Cortez          ┆   ┆        ┆        ┆               ┆          │
# └────────┴──────┴────────────┴─────────────────┴───┴────────┴────────┴───────────────┴──────────┘
# BTS
# shape: (1, 9)
# ┌────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title  ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---    ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str    ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Butter ┆ 2    ┆ 2021-05-21 ┆ BTS    ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11042335 │
# └────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# Drake
# shape: (4, 9)
# ┌────────────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title                  ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                    ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                    ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Girls Want Girls (with ┆ 1    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 12384750 │
# │ Lil Baby)              ┆      ┆            ┆        ┆   ┆        ┆        ┆           ┆          │
# │ Champagne Poetry       ┆ 2    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11696783 │
# │ Fair Trade (with       ┆ 3    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11642541 │
# │ Travis Scott)          ┆      ┆            ┆        ┆   ┆        ┆        ┆           ┆          │
# │ Papi’s Home            ┆ 5    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 10029292 │
# └────────────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# The Kid LAROI
# shape: (12, 9)
# ┌─────────────────┬──────┬────────────┬─────────┬───┬────────┬────────┬─────────────────┬──────────┐
# │ title           ┆ rank ┆ date       ┆ artist  ┆ … ┆ region ┆ chart  ┆ trend           ┆ streams  │
# │ ---             ┆ ---  ┆ ---        ┆ ---     ┆   ┆ ---    ┆ ---    ┆ ---             ┆ ---      │
# │ str             ┆ i64  ┆ date       ┆ str     ┆   ┆ str    ┆ str    ┆ str             ┆ i64      │
# ╞═════════════════╪══════╪════════════╪═════════╪═══╪════════╪════════╪═════════════════╪══════════╡
# │ STAY (with      ┆ 4    ┆ 2021-09-03 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN       ┆ 10205988 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-13 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10164435 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-14 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10098844 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-19 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10069363 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-20 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10629302 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ …               ┆ …    ┆ …          ┆ …       ┆ … ┆ …      ┆ …      ┆ …               ┆ …        │
# │ STAY (with      ┆ 1    ┆ 2021-08-24 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10054172 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-25 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10138589 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-26 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10084941 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-27 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10514624 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-28 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10205533 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# └─────────────────┴──────┴────────────┴─────────┴───┴────────┴────────┴─────────────────┴──────────┘
# Adele
# shape: (6, 9)
# ┌────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title      ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---        ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str        ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ Easy On Me ┆ 1    ┆ 2021-10-15 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 19749704 │
# │ Easy On Me ┆ 1    ┆ 2021-10-16 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 13271124 │
# │ Easy On Me ┆ 1    ┆ 2021-10-17 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10507473 │
# │ Easy On Me ┆ 1    ┆ 2021-10-18 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 11333232 │
# │ Easy On Me ┆ 1    ┆ 2021-11-19 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10407538 │
# │ Easy On Me ┆ 1    ┆ 2021-10-19 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10664000 │
# └────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────────┴──────────┘

# %% [markdown]
# Repeat this exercise but in this case grouping by the `artist` and `title` column and printing the artist and title for each group

# %%
for (artist,title), artist_df in (
    spotify_df.filter(
        pl.col("streams") > 10_000_000
    ).group_by(
        "artist", "title", maintain_order=True
    )
):
    print(artist, title)
    print(artist_df)
# Out:
# XXXTENTACION SAD!
# shape: (1, 9)
# ┌───────┬──────┬────────────┬──────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title ┆ rank ┆ date       ┆ artist       ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---   ┆ ---  ┆ ---        ┆ ---          ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str   ┆ i64  ┆ date       ┆ str          ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞═══════╪══════╪════════════╪══════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ SAD!  ┆ 1    ┆ 2018-06-19 ┆ XXXTENTACION ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10415088 │
# └───────┴──────┴────────────┴──────────────┴───┴────────┴────────┴─────────┴──────────┘
# Ariana Grande 7 rings
# shape: (1, 9)
# ┌─────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title   ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---     ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str     ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞═════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ 7 rings ┆ 1    ┆ 2019-02-08 ┆ Ariana Grande ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10445538 │
# └─────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴───────────────┴──────────┘
# Ed Sheeran I Don't Care (with Justin Bieber)
# shape: (1, 9)
# ┌────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title              ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ I Don't Care (with ┆ 1    ┆ 2019-05-10 ┆ Ed Sheeran ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 10977389 │
# │ Justin Bieber)     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# └────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴───────────┴──────────┘
# Mariah Carey All I Want for Christmas Is You
# shape: (4, 9)
# ┌───────────────┬──────┬────────────┬──────────────┬───┬────────┬────────┬──────────────┬──────────┐
# │ title         ┆ rank ┆ date       ┆ artist       ┆ … ┆ region ┆ chart  ┆ trend        ┆ streams  │
# │ ---           ┆ ---  ┆ ---        ┆ ---          ┆   ┆ ---    ┆ ---    ┆ ---          ┆ ---      │
# │ str           ┆ i64  ┆ date       ┆ str          ┆   ┆ str    ┆ str    ┆ str          ┆ i64      │
# ╞═══════════════╪══════╪════════════╪══════════════╪═══╪════════╪════════╪══════════════╪══════════╡
# │ All I Want    ┆ 1    ┆ 2018-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 10819009 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2019-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ MOVE_UP      ┆ 12028987 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2020-12-24 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 17223237 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# │ All I Want    ┆ 1    ┆ 2020-12-25 ┆ Mariah Carey ┆ … ┆ Global ┆ top200 ┆ SAME_POSITIO ┆ 13573228 │
# │ for Christmas ┆      ┆            ┆              ┆   ┆        ┆        ┆ N            ┆          │
# │ Is You        ┆      ┆            ┆              ┆   ┆        ┆        ┆              ┆          │
# └───────────────┴──────┴────────────┴──────────────┴───┴────────┴────────┴──────────────┴──────────┘
# Wham! Last Christmas
# shape: (3, 9)
# ┌────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title          ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---            ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str            ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ Last Christmas ┆ 2    ┆ 2019-12-24 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 10069590 │
# │ Last Christmas ┆ 2    ┆ 2020-12-24 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 15813799 │
# │ Last Christmas ┆ 2    ┆ 2020-12-25 ┆ Wham!  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 12415012 │
# └────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────────┴──────────┘
# Luis Fonsi Despacito (Featuring Daddy Yankee)
# shape: (1, 9)
# ┌──────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title                ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---                  ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str                  ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞══════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ Despacito (Featuring ┆ 1    ┆ 2017-05-27 ┆ Luis Fonsi ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 11381520 │
# │ Daddy Yankee)        ┆      ┆            ┆            ┆   ┆        ┆        ┆         ┆          │
# └──────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴─────────┴──────────┘
# Olivia Rodrigo drivers license
# shape: (12, 9)
# ┌─────────┬──────┬────────────┬─────────────────┬───┬────────┬────────┬─────────────────┬──────────┐
# │ title   ┆ rank ┆ date       ┆ artist          ┆ … ┆ region ┆ chart  ┆ trend           ┆ streams  │
# │ ---     ┆ ---  ┆ ---        ┆ ---             ┆   ┆ ---    ┆ ---    ┆ ---             ┆ ---      │
# │ str     ┆ i64  ┆ date       ┆ str             ┆   ┆ str    ┆ str    ┆ str             ┆ i64      │
# ╞═════════╪══════╪════════════╪═════════════════╪═══╪════════╪════════╪═════════════════╪══════════╡
# │ drivers ┆ 1    ┆ 2021-01-11 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 11510867 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-12 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 13412192 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-13 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 13628143 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-14 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 13701177 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-15 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 13714177 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ …       ┆ …    ┆ …          ┆ …               ┆ … ┆ …      ┆ …      ┆ …               ┆ …        │
# │ drivers ┆ 1    ┆ 2021-01-18 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 11486394 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-19 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 11281037 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-20 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10865246 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-21 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10370461 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# │ drivers ┆ 1    ┆ 2021-01-22 ┆ Olivia Rodrigo  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10558561 │
# │ license ┆      ┆            ┆                 ┆   ┆        ┆        ┆                 ┆          │
# └─────────┴──────┴────────────┴─────────────────┴───┴────────┴────────┴─────────────────┴──────────┘
# Ariana Grande Santa Tell Me
# shape: (1, 9)
# ┌──────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬─────────────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend           ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---             ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str             ┆ i64      │
# ╞══════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═════════════════╪══════════╡
# │ Santa Tell Me    ┆ 3    ┆ 2020-12-24 ┆ Ariana ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 12229331 │
# │                  ┆      ┆            ┆ Grande ┆   ┆        ┆        ┆                 ┆          │
# └──────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴─────────────────┴──────────┘
# Michael Bublé It's Beginning to Look a Lot like Christmas
# shape: (2, 9)
# ┌─────────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title           ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---             ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str             ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞═════════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ It's Beginning  ┆ 4    ┆ 2020-12-24 ┆ Michael Bublé ┆ … ┆ Global ┆ top200 ┆ MOVE_UP   ┆ 11975033 │
# │ to Look a Lot   ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ like Christmas  ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ It's Beginning  ┆ 5    ┆ 2020-12-25 ┆ Michael Bublé ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN ┆ 10023249 │
# │ to Look a Lot   ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# │ like Christmas  ┆      ┆            ┆               ┆   ┆        ┆        ┆           ┆          │
# └─────────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴───────────┴──────────┘
# Bobby Helms Jingle Bell Rock
# shape: (2, 9)
# ┌──────────────────┬──────┬────────────┬─────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist      ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---         ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str         ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞══════════════════╪══════╪════════════╪═════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ Jingle Bell Rock ┆ 5    ┆ 2020-12-24 ┆ Bobby Helms ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 11924353 │
# │ Jingle Bell Rock ┆ 4    ┆ 2020-12-25 ┆ Bobby Helms ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10680793 │
# └──────────────────┴──────┴────────────┴─────────────┴───┴────────┴────────┴─────────┴──────────┘
# Brenda Lee Rockin' Around The Christmas Tree
# shape: (2, 9)
# ┌────────────────────┬──────┬────────────┬────────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title              ┆ rank ┆ date       ┆ artist     ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                ┆ ---  ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                ┆ i64  ┆ date       ┆ str        ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════╪══════╪════════════╪════════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Rockin' Around The ┆ 6    ┆ 2020-12-24 ┆ Brenda Lee ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN ┆ 11801426 │
# │ Christmas Tree     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# │ Rockin' Around The ┆ 3    ┆ 2020-12-25 ┆ Brenda Lee ┆ … ┆ Global ┆ top200 ┆ MOVE_UP   ┆ 10893485 │
# │ Christmas Tree     ┆      ┆            ┆            ┆   ┆        ┆        ┆           ┆          │
# └────────────────────┴──────┴────────────┴────────────┴───┴────────┴────────┴───────────┴──────────┘
# Andy Williams It's the Most Wonderful Time of the Year
# shape: (1, 9)
# ┌───────────────────┬──────┬────────────┬───────────────┬───┬────────┬────────┬─────────┬──────────┐
# │ title             ┆ rank ┆ date       ┆ artist        ┆ … ┆ region ┆ chart  ┆ trend   ┆ streams  │
# │ ---               ┆ ---  ┆ ---        ┆ ---           ┆   ┆ ---    ┆ ---    ┆ ---     ┆ ---      │
# │ str               ┆ i64  ┆ date       ┆ str           ┆   ┆ str    ┆ str    ┆ str     ┆ i64      │
# ╞═══════════════════╪══════╪════════════╪═══════════════╪═══╪════════╪════════╪═════════╪══════════╡
# │ It's the Most     ┆ 7    ┆ 2020-12-24 ┆ Andy Williams ┆ … ┆ Global ┆ top200 ┆ MOVE_UP ┆ 10429582 │
# │ Wonderful Time of ┆      ┆            ┆               ┆   ┆        ┆        ┆         ┆          │
# │ the Year          ┆      ┆            ┆               ┆   ┆        ┆        ┆         ┆          │
# └───────────────────┴──────┴────────────┴───────────────┴───┴────────┴────────┴─────────┴──────────┘
# Bad Bunny, Jhay Cortez DÁKITI
# shape: (1, 9)
# ┌────────┬──────┬────────────┬─────────────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title  ┆ rank ┆ date       ┆ artist          ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---    ┆ ---  ┆ ---        ┆ ---             ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str    ┆ i64  ┆ date       ┆ str             ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════╪══════╪════════════╪═════════════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ DÁKITI ┆ 1    ┆ 2020-11-27 ┆ Bad Bunny, Jhay ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10086143 │
# │        ┆      ┆            ┆ Cortez          ┆   ┆        ┆        ┆               ┆          │
# └────────┴──────┴────────────┴─────────────────┴───┴────────┴────────┴───────────────┴──────────┘
# Olivia Rodrigo good 4 u
# shape: (16, 9)
# ┌──────────┬──────┬────────────┬────────────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title    ┆ rank ┆ date       ┆ artist         ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---      ┆ ---  ┆ ---        ┆ ---            ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str      ┆ i64  ┆ date       ┆ str            ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞══════════╪══════╪════════════╪════════════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ good 4 u ┆ 1    ┆ 2021-06-01 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 11155793 │
# │ good 4 u ┆ 1    ┆ 2021-06-02 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10981883 │
# │ good 4 u ┆ 1    ┆ 2021-06-03 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10650862 │
# │ good 4 u ┆ 1    ┆ 2021-06-04 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10773374 │
# │ good 4 u ┆ 1    ┆ 2021-06-05 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10149002 │
# │ …        ┆ …    ┆ …          ┆ …              ┆ … ┆ …      ┆ …      ┆ …             ┆ …        │
# │ good 4 u ┆ 1    ┆ 2021-05-27 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 12292053 │
# │ good 4 u ┆ 1    ┆ 2021-05-28 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 11768671 │
# │ good 4 u ┆ 1    ┆ 2021-05-29 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 11365323 │
# │ good 4 u ┆ 1    ┆ 2021-05-30 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10251400 │
# │ good 4 u ┆ 1    ┆ 2021-05-31 ┆ Olivia Rodrigo ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10827936 │
# └──────────┴──────┴────────────┴────────────────┴───┴────────┴────────┴───────────────┴──────────┘
# BTS Butter
# shape: (1, 9)
# ┌────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title  ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---    ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str    ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Butter ┆ 2    ┆ 2021-05-21 ┆ BTS    ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11042335 │
# └────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# Drake Girls Want Girls (with Lil Baby)
# shape: (1, 9)
# ┌────────────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title                  ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---                    ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str                    ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞════════════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Girls Want Girls (with ┆ 1    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 12384750 │
# │ Lil Baby)              ┆      ┆            ┆        ┆   ┆        ┆        ┆           ┆          │
# └────────────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# Drake Champagne Poetry
# shape: (1, 9)
# ┌──────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞══════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Champagne Poetry ┆ 2    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11696783 │
# └──────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# Drake Fair Trade (with Travis Scott)
# shape: (1, 9)
# ┌──────────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title            ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---              ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str              ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞══════════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Fair Trade (with ┆ 3    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 11642541 │
# │ Travis Scott)    ┆      ┆            ┆        ┆   ┆        ┆        ┆           ┆          │
# └──────────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# The Kid LAROI STAY (with Justin Bieber)
# shape: (12, 9)
# ┌─────────────────┬──────┬────────────┬─────────┬───┬────────┬────────┬─────────────────┬──────────┐
# │ title           ┆ rank ┆ date       ┆ artist  ┆ … ┆ region ┆ chart  ┆ trend           ┆ streams  │
# │ ---             ┆ ---  ┆ ---        ┆ ---     ┆   ┆ ---    ┆ ---    ┆ ---             ┆ ---      │
# │ str             ┆ i64  ┆ date       ┆ str     ┆   ┆ str    ┆ str    ┆ str             ┆ i64      │
# ╞═════════════════╪══════╪════════════╪═════════╪═══╪════════╪════════╪═════════════════╪══════════╡
# │ STAY (with      ┆ 4    ┆ 2021-09-03 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ MOVE_DOWN       ┆ 10205988 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-13 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10164435 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-14 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10098844 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-19 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10069363 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-20 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10629302 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ …               ┆ …    ┆ …          ┆ …       ┆ … ┆ …      ┆ …      ┆ …               ┆ …        │
# │ STAY (with      ┆ 1    ┆ 2021-08-24 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10054172 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-25 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10138589 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-26 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10084941 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-27 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10514624 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# │ STAY (with      ┆ 1    ┆ 2021-08-28 ┆ The Kid ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION   ┆ 10205533 │
# │ Justin Bieber)  ┆      ┆            ┆ LAROI   ┆   ┆        ┆        ┆                 ┆          │
# └─────────────────┴──────┴────────────┴─────────┴───┴────────┴────────┴─────────────────┴──────────┘
# Drake Papi’s Home
# shape: (1, 9)
# ┌─────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────┬──────────┐
# │ title       ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend     ┆ streams  │
# │ ---         ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---       ┆ ---      │
# │ str         ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str       ┆ i64      │
# ╞═════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════╪══════════╡
# │ Papi’s Home ┆ 5    ┆ 2021-09-03 ┆ Drake  ┆ … ┆ Global ┆ top200 ┆ NEW_ENTRY ┆ 10029292 │
# └─────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────┴──────────┘
# Adele Easy On Me
# shape: (6, 9)
# ┌────────────┬──────┬────────────┬────────┬───┬────────┬────────┬───────────────┬──────────┐
# │ title      ┆ rank ┆ date       ┆ artist ┆ … ┆ region ┆ chart  ┆ trend         ┆ streams  │
# │ ---        ┆ ---  ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---           ┆ ---      │
# │ str        ┆ i64  ┆ date       ┆ str    ┆   ┆ str    ┆ str    ┆ str           ┆ i64      │
# ╞════════════╪══════╪════════════╪════════╪═══╪════════╪════════╪═══════════════╪══════════╡
# │ Easy On Me ┆ 1    ┆ 2021-10-15 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ MOVE_UP       ┆ 19749704 │
# │ Easy On Me ┆ 1    ┆ 2021-10-16 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 13271124 │
# │ Easy On Me ┆ 1    ┆ 2021-10-17 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10507473 │
# │ Easy On Me ┆ 1    ┆ 2021-10-18 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 11333232 │
# │ Easy On Me ┆ 1    ┆ 2021-11-19 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10407538 │
# │ Easy On Me ┆ 1    ┆ 2021-10-19 ┆ Adele  ┆ … ┆ Global ┆ top200 ┆ SAME_POSITION ┆ 10664000 │
# └────────────┴──────┴────────────┴────────┴───┴────────┴────────┴───────────────┴──────────┘

# %% [markdown]
# Find the total number of streams by artist for tracks that are number 1 in the charts.
#
# Divide the number of streams by 1 million to make it easier to read and sort from high to low

# %%
spotify_df.filter(
    pl.col("rank") == 1
).group_by(
    "artist", "title"
).agg(
    streams = (pl.col("streams").sum() / 1_000_000)
).sort("streams", descending=True)
# Out:
# shape: (72, 3)
# ┌──────────────────────────────┬──────────────────────────────────┬────────────┐
# │ artist                       ┆ title                            ┆ streams    │
# │ ---                          ┆ ---                              ┆ ---        │
# │ str                          ┆ str                              ┆ f64        │
# ╞══════════════════════════════╪══════════════════════════════════╪════════════╡
# │ Tones And I                  ┆ Dance Monkey                     ┆ 774.484772 │
# │ Shawn Mendes, Camila Cabello ┆ Señorita                         ┆ 742.596967 │
# │ Ed Sheeran                   ┆ Shape of You                     ┆ 702.18693  │
# │ The Kid LAROI                ┆ STAY (with Justin Bieber)        ┆ 677.106038 │
# │ Post Malone, 21 Savage       ┆ rockstar                         ┆ 621.760044 │
# │ …                            ┆ …                                ┆ …          │
# │ Lil Wayne                    ┆ Mona Lisa (feat. Kendrick Lamar) ┆ 5.808198   │
# │ Eminem                       ┆ The Ringer                       ┆ 5.18659    │
# │ Billie Eilish                ┆ my future                        ┆ 5.183389   │
# │ Post Malone                  ┆ Wow.                             ┆ 4.570136   │
# │ Kanye West                   ┆ All Mine                         ┆ 4.536998   │
# └──────────────────────────────┴──────────────────────────────────┴────────────┘

# %% [markdown]
# Using one of the methods we can call directly on `group_by` find out how many distinct tracks each artist has.
#
# Sort the values from high to low

# %%
spotify_df.group_by("artist").n_unique().select(
    "artist", "title"
).sort("title", descending=True)

# n_unique counts the distinct values
# Out:
# shape: (2_223, 2)
# ┌──────────────────────────────────────────────────┬───────┐
# │ artist                                           ┆ title │
# │ ---                                              ┆ ---   │
# │ str                                              ┆ u32   │
# ╞══════════════════════════════════════════════════╪═══════╡
# │ Taylor Swift                                     ┆ 128   │
# │ Drake                                            ┆ 95    │
# │ BTS                                              ┆ 76    │
# │ Juice WRLD                                       ┆ 72    │
# │ Eminem                                           ┆ 63    │
# │ …                                                ┆ …     │
# │ YTB Trench, Young Stoner Life, Young Thug, Gunna ┆ 1     │
# │ Chance the Rapper, TisaKorean, Murda Beatz       ┆ 1     │
# │ Lil Kleine, Boef                                 ┆ 1     │
# │ Drake, Static Major, Ty Dolla $ign               ┆ 1     │
# │ Kygo, Sasha Sloan                                ┆ 1     │
# └──────────────────────────────────────────────────┴───────┘
